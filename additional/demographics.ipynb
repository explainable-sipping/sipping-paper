# %%
import pandas as pd
import numpy as np
import shap
import warnings
import joblib
import sys
import psutil
import GPUtil
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, cross_validate, GroupKFold, cross_val_predict, ParameterGrid
from collections import defaultdict
from time import time
from datetime import timedelta
from importlib.metadata import version

# printout of python version
print("="*50, "Python Version", "="*50)
print(f"python version: {sys.version}")
print(f"xgboost:        {version('xgboost')}")
print(f"shap:           {version('shap')}")

# printout of hardware
print("="*50, "Hardware", "="*50)
gpus = GPUtil.getGPUs()
for gpu in gpus:
    print(f"GPU: {gpu.name}")
print(f"CPU cores: {psutil.cpu_count(logical=False)}")
print(f"RAM: {psutil.virtual_memory().total / 1024 / 1024 / 1024 :.2f} GB")

warnings.filterwarnings('ignore')
# Out:
# ================================================== Python Version ==================================================
# python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# xgboost:        2.1.1
# shap:           0.46.0
# ================================================== Hardware ==================================================
# GPU: NVIDIA GeForce RTX 4090
# CPU cores: 16
# RAM: 63.82 GB

# %% [markdown]
# # read data function

# %%
def read_abcd(path, cols, na_values):
    
    df = pd.read_csv(path, sep='\t', index_col='subjectkey', na_values=na_values)
    df = df.drop(df.index[0])
    
    for col in cols:
        df[col] = pd.to_numeric(df[col])
        df = df[cols]

    df = df.reset_index()
    df = df.sort_values(['subjectkey', 'interview_age'])
    df = df.drop_duplicates(subset=['subjectkey'], keep='first')
    df = df.drop(columns=['interview_age'])
    df = df.set_index('subjectkey')
    
    df_show = abcd_ysu02.join(df)
    df_show = df_show.drop(columns=[
        'isip_1d_2',
        'isip_5_2',
        'isip_1b_yn'
    ])
     
    for col in df_show.columns:
        print('{:<30}    n = {:<10}    mean = {:<10.4f}    sum = {:<10.1f}'.\
              format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
    print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
    
    return df

# %% [markdown]
# # y-target variable

# %%
file_abcd_ysu02 = r'D:\gregn\data\ABCD\abcd3\abcd_ysu02.txt'
abcd_ysu02 = pd.read_csv(file_abcd_ysu02, sep='\t', index_col='subjectkey')
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02.index[0])
cols = [
    'interview_age',
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
]

for col in cols:
    abcd_ysu02[col] = pd.to_numeric(abcd_ysu02[col])
    abcd_ysu02 = abcd_ysu02[cols]
    
abcd_ysu02 = abcd_ysu02.reset_index()
abcd_ysu02 = abcd_ysu02.sort_values(['subjectkey', 'interview_age'])
abcd_ysu02 = abcd_ysu02.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_ysu02 = abcd_ysu02.drop(columns=['interview_age'])
abcd_ysu02 = abcd_ysu02.set_index('subjectkey')
    
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_5_2 == 3].index) # drop accidental 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_5_2 == 2].index) # drop furtive 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_1b_yn == 0].index) # drop religious 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_1d_2 > 10].index) # drop older than 10

abcd_ysu02['isip_1d_2'] = abcd_ysu02['isip_1d_2'].fillna(0)

y = abcd_ysu02['isip_1d_2'].values
y = np.where(y>0, 1, y)

unique, counts = np.unique(y, return_counts=True)

print('number of subjects: {:>10}\n\n[0] never sipped: {:>12}\n[1] sipped by age 10:{:>9}'.\
      format(len(y), counts[0], counts[1]))
# Out:
# number of subjects:      10707
#
# [0] never sipped:         9209
# [1] sipped by age 10:     1498

# %% [markdown]
# # pdem02

# %%
file_pdem02 = r'D:\gregn\data\ABCD\abcd3\pdem02.txt'
pdem02 = pd.read_csv(file_pdem02, sep='\t', index_col='subjectkey', na_values=['777', '999'])
pdem02 = pdem02.drop(pdem02.index[0])

cols = [
    'interview_age',
    'demo_prim',
    'demo_adopt_agex_v2',
    'demo_sex_v2',
    'demo_gender_id_v2',
    'demo_prnt_age_v2',
    'demo_prnt_gender_id_v2',
    'demo_prnt_marital_v2',
    'demo_prnt_ed_v2',
    'demo_prnt_empl_v2',
    'demo_prnt_empl_time',
    'demo_prnt_income_v2',
    'demo_prnt_prtnr_v2',
    'demo_comb_income_v2',
    'demo_fam_exp1_v2',
    'demo_fam_exp2_v2',
    'demo_fam_exp3_v2',
    'demo_fam_exp4_v2',
    'demo_fam_exp5_v2',
    'demo_fam_exp6_v2',
    'demo_fam_exp7_v2'
]

for col in cols:
    pdem02[col] = pd.to_numeric(pdem02[col])
    pdem02 = pdem02[cols]
    
pdem02 = pd.get_dummies(pdem02, columns=[
    'demo_prim',
    'demo_sex_v2',
    'demo_gender_id_v2',
    'demo_prnt_gender_id_v2',
    'demo_prnt_marital_v2',
    'demo_prnt_empl_v2',
], dtype=float)

pdem02 = pdem02.rename(columns={
    'demo_prim_1': 'demo_prim_biological_mother',
    'demo_prim_2': 'demo_prim_biological_father',
    'demo_prim_3': 'demo_prim_adoptive_parent',
    'demo_prim_4': 'demo_prim_custodial_parent',
    'demo_prim_5': 'demo_prim_other',
    'demo_sex_v2_1': 'demo_sex_v2_male',
    'demo_sex_v2_2': 'demo_sex_v2_female',
    'demo_sex_v2_3': 'demo_sex_v2_intersex-male', 
    'demo_gender_id_v2_1.0': 'demo_gender_id_v2_male',
    'demo_gender_id_v2_2.0': 'demo_gender_id_v2_female',
    'demo_gender_id_v2_3.0': 'demo_gender_id_v2_trans_male',
    'demo_gender_id_v2_4.0': 'demo_gender_id_v2_trans_female',
    'demo_gender_id_v2_5.0': 'demo_gender_id_v2_gender_queer',
    'demo_gender_id_v2_6.0': 'demo_gender_id_v2_different',
    'demo_prnt_gender_id_v2_1.0': 'demo_prnt_gender_id_v2_male',
    'demo_prnt_gender_id_v2_2.0': 'demo_prnt_gender_id_v2_female',
    'demo_prnt_gender_id_v2_3.0': 'demo_prnt_gender_id_v2_trans_male',
    'demo_prnt_gender_id_v2_4.0': 'demo_prnt_gender_id_v2_trans_female',
    'demo_prnt_gender_id_v2_5.0': 'demo_prnt_gender_id_v2_gender_queer',
    'demo_prnt_gender_id_v2_6.0': 'demo_prnt_gender_id_v2_different',
    'demo_prnt_marital_v2_1.0': 'demo_prnt_marital_v2_married',
    'demo_prnt_marital_v2_2.0': 'demo_prnt_marital_v2_widowed',
    'demo_prnt_marital_v2_3.0': 'demo_prnt_marital_v2_divorced',
    'demo_prnt_marital_v2_4.0': 'demo_prnt_marital_v2_separated',
    'demo_prnt_marital_v2_5.0': 'demo_prnt_marital_v2_never_married',
    'demo_prnt_marital_v2_6.0': 'demo_prnt_marital_v2_living_with_partner',
    'demo_prnt_empl_v2_1.0': 'demo_prnt_empl_v2_working_now',
    'demo_prnt_empl_v2_2.0': 'demo_prnt_empl_v2_temporarily_laid_off',
    'demo_prnt_empl_v2_3.0': 'demo_prnt_empl_v2_looking_for_work',
    'demo_prnt_empl_v2_4.0': 'demo_prnt_empl_v2_retired',
    'demo_prnt_empl_v2_5.0': 'demo_prnt_empl_v2_disabled',
    'demo_prnt_empl_v2_6.0': 'demo_prnt_empl_v2_stay_at_home_parent',
    'demo_prnt_empl_v2_7.0': 'demo_prnt_empl_v2_student',
    'demo_prnt_empl_v2_8.0': 'demo_prnt_empl_v2_other',
    'demo_prnt_empl_v2_9.0': 'demo_prnt_empl_v2_sick_leave',
    'demo_prnt_empl_v2_10.0': 'demo_prnt_empl_v2_maternity_leave',
    'demo_prnt_empl_v2_11.0': 'demo_prnt_empl_v2_unemployed_not_looking'   
})


pdem02['demo_gender_id_v2_non-binary'] = (pdem02.demo_gender_id_v2_trans_male
                                         + pdem02.demo_gender_id_v2_trans_female
                                         + pdem02.demo_gender_id_v2_gender_queer
                                         + pdem02.demo_gender_id_v2_different)

pdem02['demo_prnt_gender_id_v2_non-binary'] = (pdem02.demo_prnt_gender_id_v2_trans_male
                                              + pdem02.demo_prnt_gender_id_v2_trans_female
                                              + pdem02.demo_prnt_gender_id_v2_gender_queer
                                              + pdem02.demo_prnt_gender_id_v2_different)


pdem02 = pdem02.drop(columns=[
    'demo_gender_id_v2_trans_male',
    'demo_gender_id_v2_trans_female',
    'demo_gender_id_v2_gender_queer',
    'demo_gender_id_v2_different',
    'demo_prnt_gender_id_v2_trans_male',
    'demo_prnt_gender_id_v2_trans_female',
    'demo_prnt_gender_id_v2_gender_queer',
    'demo_prnt_gender_id_v2_different',
    'demo_sex_v2_intersex-male'
])

pdem02 = pdem02.reset_index()
pdem02 = pdem02.sort_values(['subjectkey', 'interview_age'])
pdem02 = pdem02.drop_duplicates(subset=['subjectkey'], keep='first')
#pdem02 = pdem02.drop(columns=['interview_age'])
pdem02 = pdem02.set_index('subjectkey')

df_show = abcd_ysu02.join(pdem02)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<40}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# interview_age                               n = 10707         mean = 118.8987      sum = 1273048
# demo_adopt_agex_v2                          n = 252           mean = 2.2289        sum = 561.68
# demo_prnt_age_v2                            n = 10620         mean = 39.8566       sum = 423277.1
# demo_prnt_ed_v2                             n = 10692         mean = 16.5397       sum = 176843.0
# demo_prnt_empl_time                         n = 7314          mean = 1.2740        sum = 9318.0
# demo_prnt_income_v2                         n = 9699          mean = 4.8610        sum = 47147.0
# demo_prnt_prtnr_v2                          n = 10594         mean = 1.1937        sum = 12646.0
# demo_comb_income_v2                         n = 9772          mean = 7.1823        sum = 70185.0
# demo_fam_exp1_v2                            n = 10632         mean = 0.0837        sum = 890.0
# demo_fam_exp2_v2                            n = 10661         mean = 0.0623        sum = 664.0
# demo_fam_exp3_v2                            n = 10649         mean = 0.1097        sum = 1168.0
# demo_fam_exp4_v2                            n = 10676         mean = 0.0148        sum = 158.0
# demo_fam_exp5_v2                            n = 10664         mean = 0.0571        sum = 609.0
# demo_fam_exp6_v2                            n = 10668         mean = 0.0529        sum = 564.0
# demo_fam_exp7_v2                            n = 10661         mean = 0.1040        sum = 1109.0
# demo_prim_biological_mother                 n = 10707         mean = 0.8522        sum = 9125.0
# demo_prim_biological_father                 n = 10707         mean = 0.1000        sum = 1071.0
# demo_prim_adoptive_parent                   n = 10707         mean = 0.0239        sum = 256.0
# demo_prim_custodial_parent                  n = 10707         mean = 0.0104        sum = 111.0
# demo_prim_other                             n = 10707         mean = 0.0134        sum = 144.0
# demo_sex_v2_male                            n = 10707         mean = 0.5189        sum = 5556.0
# demo_sex_v2_female                          n = 10707         mean = 0.4807        sum = 5147.0
# demo_gender_id_v2_male                      n = 10707         mean = 0.5183        sum = 5549.0
# demo_gender_id_v2_female                    n = 10707         mean = 0.4797        sum = 5136.0
# demo_prnt_gender_id_v2_male                 n = 10707         mean = 0.1088        sum = 1165.0
# demo_prnt_gender_id_v2_female               n = 10707         mean = 0.8887        sum = 9515.0
# demo_prnt_marital_v2_married                n = 10707         mean = 0.6717        sum = 7192.0
# demo_prnt_marital_v2_widowed                n = 10707         mean = 0.0083        sum = 89.0
# demo_prnt_marital_v2_divorced               n = 10707         mean = 0.0899        sum = 963.0
# demo_prnt_marital_v2_separated              n = 10707         mean = 0.0390        sum = 418.0
# demo_prnt_marital_v2_never_married          n = 10707         mean = 0.1246        sum = 1334.0
# demo_prnt_marital_v2_living_with_partner    n = 10707         mean = 0.0580        sum = 621.0
# demo_prnt_empl_v2_working_now               n = 10707         mean = 0.6856        sum = 7341.0
# demo_prnt_empl_v2_temporarily_laid_off      n = 10707         mean = 0.0080        sum = 86.0
# demo_prnt_empl_v2_looking_for_work          n = 10707         mean = 0.0424        sum = 454.0
# demo_prnt_empl_v2_retired                   n = 10707         mean = 0.0062        sum = 66.0
# demo_prnt_empl_v2_disabled                  n = 10707         mean = 0.0228        sum = 244.0
# demo_prnt_empl_v2_stay_at_home_parent       n = 10707         mean = 0.1783        sum = 1909.0
# demo_prnt_empl_v2_student                   n = 10707         mean = 0.0209        sum = 224.0
# demo_prnt_empl_v2_other                     n = 10707         mean = 0.0191        sum = 205.0
# demo_prnt_empl_v2_sick_leave                n = 10707         mean = 0.0017        sum = 18.0
# demo_prnt_empl_v2_maternity_leave           n = 10707         mean = 0.0025        sum = 27.0
# demo_prnt_empl_v2_unemployed_not_looking    n = 10707         mean = 0.0076        sum = 81.0
# demo_gender_id_v2_non-binary                n = 10707         mean = 0.0011        sum = 12.0
# demo_prnt_gender_id_v2_non-binary           n = 10707         mean = 0.0020        sum = 21.0
#
# subjects:     10707
# features:        45

# %%
pdem02 = pdem02['demo_sex_v2_male']
pdem02
# Out:
# subjectkey
# NDARMC003PZF        0.0
# NDAR_INV003RTV85    0.0
# NDAR_INV005V6D2C    0.0
# NDAR_INV007W6H7B    1.0
# NDAR_INV00BD7VDC    1.0
#                    ...
# NDAR_INVZZNX6W2P    1.0
# NDAR_INVZZPKBDAC    0.0
# NDAR_INVZZZ2ALR6    0.0
# NDAR_INVZZZNB0XC    0.0
# NDAR_INVZZZP87KR    0.0
# Name: demo_sex_v2_male, Length: 11878, dtype: float64

# %% [markdown]
# # abcd_meim01

# %%
file_abcd_meim01 = r'D:\gregn\data\ABCD\abcd3\abcd_meim01.txt'
abcd_meim01 = pd.read_csv(file_abcd_meim01, sep='\t', index_col='subjectkey', na_values=['777', '999'])
abcd_meim01 = abcd_meim01.drop(abcd_meim01.index[0])

cols = [
    'interview_age',
    'meim_ethnic_id_p',
]

for col in cols:
    abcd_meim01[col] = pd.to_numeric(abcd_meim01[col])
    abcd_meim01 = abcd_meim01[cols]

abcd_meim01 = pd.get_dummies(abcd_meim01, columns=['meim_ethnic_id_p'], dtype=float)

abcd_meim01 = abcd_meim01.rename(columns={
    'meim_ethnic_id_p_0.0': 'meim_ethnic_id_p_none',
    'meim_ethnic_id_p_1.0': 'meim_ethnic_id_p_white/caucasian',
    'meim_ethnic_id_p_2.0': 'meim_ethnic_id_p_western_european',
    'meim_ethnic_id_p_3.0': 'meim_ethnic_id_p_eastern_european',
    'meim_ethnic_id_p_4.0': 'meim_ethnic_id_p_hispanic/latino',
    'meim_ethnic_id_p_5.0': 'meim_ethnic_id_p_black/african_american',
    'meim_ethnic_id_p_6.0': 'meim_ethnic_id_p_afro-carribean/indo-carribbean/west_indian',
    'meim_ethnic_id_p_7.0': 'meim_ethnic_id_p_east_asian',
    'meim_ethnic_id_p_8.0': 'meim_ethnic_id_p_south_asian',
    'meim_ethnic_id_p_9.0': 'meim_ethnic_id_p_southeast_asian',
    'meim_ethnic_id_p_10.0': 'meim_ethnic_id_p_american_indian/alaska_native',
    'meim_ethnic_id_p_11.0': 'meim_ethnic_id_p_middle_eastern/north_african',
    'meim_ethnic_id_p_12.0': 'meim_ethnic_id_p_native_hawaiian_or_pacific_islander',
    'meim_ethnic_id_p_13.0': 'meim_ethnic_id_p_mixed',
    'meim_ethnic_id_p_14.0': 'meim_ethnic_id_p_other'
})

abcd_meim01 = abcd_meim01.reset_index()
abcd_meim01 = abcd_meim01.sort_values(['subjectkey', 'interview_age'])
abcd_meim01 = abcd_meim01.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_meim01 = abcd_meim01.drop(columns=['interview_age'])
abcd_meim01 = abcd_meim01.set_index('subjectkey')

df_show = abcd_ysu02.join(abcd_meim01)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<60}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# meim_ethnic_id_p_none                                           n = 10707         mean = 0.0663        sum = 710.0
# meim_ethnic_id_p_white/caucasian                                n = 10707         mean = 0.5314        sum = 5690.0
# meim_ethnic_id_p_western_european                               n = 10707         mean = 0.0128        sum = 137.0
# meim_ethnic_id_p_eastern_european                               n = 10707         mean = 0.0040        sum = 43.0
# meim_ethnic_id_p_hispanic/latino                                n = 10707         mean = 0.1455        sum = 1558.0
# meim_ethnic_id_p_black/african_american                         n = 10707         mean = 0.1454        sum = 1557.0
# meim_ethnic_id_p_afro-carribean/indo-carribbean/west_indian     n = 10707         mean = 0.0028        sum = 30.0
# meim_ethnic_id_p_east_asian                                     n = 10707         mean = 0.0182        sum = 195.0
# meim_ethnic_id_p_south_asian                                    n = 10707         mean = 0.0048        sum = 51.0
# meim_ethnic_id_p_southeast_asian                                n = 10707         mean = 0.0099        sum = 106.0
# meim_ethnic_id_p_american_indian/alaska_native                  n = 10707         mean = 0.0069        sum = 74.0
# meim_ethnic_id_p_middle_eastern/north_african                   n = 10707         mean = 0.0029        sum = 31.0
# meim_ethnic_id_p_native_hawaiian_or_pacific_islander            n = 10707         mean = 0.0021        sum = 22.0
# meim_ethnic_id_p_mixed                                          n = 10707         mean = 0.0255        sum = 273.0
# meim_ethnic_id_p_other                                          n = 10707         mean = 0.0029        sum = 31.0
#
# subjects:     10707
# features:        15

# %% [markdown]
# # abcd_lt01

# %%
file_abcd_lt01 = r'D:\gregn\data\ABCD\abcd3\abcd_lt01.txt'

abcd_lt01 = pd.read_csv(file_abcd_lt01, sep='\t', index_col='subjectkey')
abcd_lt01 = abcd_lt01.drop(abcd_lt01.index[0])

cols = [
    'interview_age',
    'site_id_l'
]

abcd_lt01 = pd.get_dummies(abcd_lt01, columns=['site_id_l'], dtype=float)

abcd_lt01 = abcd_lt01.reset_index()
abcd_lt01 = abcd_lt01.sort_values(['subjectkey', 'interview_age'])
abcd_lt01 = abcd_lt01.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_lt01 = abcd_lt01.drop(columns=['interview_age'])
abcd_lt01 = abcd_lt01.set_index('subjectkey')

abcd_lt01 = abcd_lt01.iloc[:, 8:]

df_show = abcd_ysu02.join(abcd_lt01)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<40}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# site_id_l_site01                            n = 10707         mean = 0.0345        sum = 369.0
# site_id_l_site02                            n = 10707         mean = 0.0468        sum = 501.0
# site_id_l_site03                            n = 10707         mean = 0.0531        sum = 569.0
# site_id_l_site04                            n = 10707         mean = 0.0616        sum = 660.0
# site_id_l_site05                            n = 10707         mean = 0.0311        sum = 333.0
# site_id_l_site06                            n = 10707         mean = 0.0497        sum = 532.0
# site_id_l_site07                            n = 10707         mean = 0.0280        sum = 300.0
# site_id_l_site08                            n = 10707         mean = 0.0289        sum = 309.0
# site_id_l_site09                            n = 10707         mean = 0.0357        sum = 382.0
# site_id_l_site10                            n = 10707         mean = 0.0616        sum = 660.0
# site_id_l_site11                            n = 10707         mean = 0.0389        sum = 416.0
# site_id_l_site12                            n = 10707         mean = 0.0511        sum = 547.0
# site_id_l_site13                            n = 10707         mean = 0.0609        sum = 652.0
# site_id_l_site14                            n = 10707         mean = 0.0511        sum = 547.0
# site_id_l_site15                            n = 10707         mean = 0.0399        sum = 427.0
# site_id_l_site16                            n = 10707         mean = 0.0910        sum = 974.0
# site_id_l_site17                            n = 10707         mean = 0.0472        sum = 505.0
# site_id_l_site18                            n = 10707         mean = 0.0309        sum = 331.0
# site_id_l_site19                            n = 10707         mean = 0.0468        sum = 501.0
# site_id_l_site20                            n = 10707         mean = 0.0591        sum = 633.0
# site_id_l_site21                            n = 10707         mean = 0.0494        sum = 529.0
# site_id_l_site22                            n = 10707         mean = 0.0028        sum = 30.0
#
# subjects:     10707
# features:        22

# %% [markdown]
# # acspsw03

# %%
path = r'D:\gregn\data\ABCD\abcd3\acspsw03.txt'

cols = [
    'interview_age',
    'rel_family_id',
]

na_values = [None]
acspsw03 = read_abcd(path, cols, na_values)
# Out:
# rel_family_id                     n = 10707         mean = 5921.1416     sum = 63397663.0
#
# subjects:     10707
# features:         1

# %% [markdown]
# # join dataframes

# %%
dfs = [
    abcd_ysu02,
    pdem02,
    abcd_meim01,
    acspsw03,
    abcd_lt01,
]

abcd = dfs[0].join(dfs[1:])
print('number of subjects:', len(abcd))
# Out:
# number of subjects: 10707

# %% [markdown]
# # X features

# %%
X = abcd.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn',
    'rel_family_id'
])
X_values = X.values
print('number of features:', X.shape[1])
list(X.columns)
# Out:
# number of features: 38
# ['demo_sex_v2_male',
#  'meim_ethnic_id_p_none',
#  'meim_ethnic_id_p_white/caucasian',
#  'meim_ethnic_id_p_western_european',
#  'meim_ethnic_id_p_eastern_european',
#  'meim_ethnic_id_p_hispanic/latino',
#  'meim_ethnic_id_p_black/african_american',
#  'meim_ethnic_id_p_afro-carribean/indo-carribbean/west_indian',
#  'meim_ethnic_id_p_east_asian',
#  'meim_ethnic_id_p_south_asian',
#  'meim_ethnic_id_p_southeast_asian',
#  'meim_ethnic_id_p_american_indian/alaska_native',
#  'meim_ethnic_id_p_middle_eastern/north_african',
#  'meim_ethnic_id_p_native_hawaiian_or_pacific_islander',
#  'meim_ethnic_id_p_mixed',
#  'meim_ethnic_id_p_other',
#  'site_id_l_site01',
#  'site_id_l_site02',
#  'site_id_l_site03',
#  'site_id_l_site04',
#  'site_id_l_site05',
#  'site_id_l_site06',
#  'site_id_l_site07',
#  'site_id_l_site08',
#  'site_id_l_site09',
#  'site_id_l_site10',
#  'site_id_l_site11',
#  'site_id_l_site12',
#  'site_id_l_site13',
#  'site_id_l_site14',
#  'site_id_l_site15',
#  'site_id_l_site16',
#  'site_id_l_site17',
#  'site_id_l_site18',
#  'site_id_l_site19',
#  'site_id_l_site20',
#  'site_id_l_site21',
#  'site_id_l_site22']

# %% [markdown]
# # family groups

# %%
d = defaultdict(lambda: len(d))
family_groups = [d[x] for x in abcd['rel_family_id']]
family_groups = np.array(family_groups)
print(f"there are {len(np.unique(family_groups))} unique family groups")
# Out:
# there are 9011 unique family groups

# %% [markdown]
# # XGBoost: 5x5 nested cross validation

# %%
start_time = time()

model = XGBClassifier(
    tree_method = 'gpu_hist',
    objective = 'binary:logistic',
    eval_metric = 'auc',
    random_state = 42, 
)

# hyperparameter grid
params = {
    'learning_rate': [0.005, 0.01, 0.1],
    'max_depth': [4, 6, 8],
    'n_estimators': [100, 500, 1000, 1500, 2000, 2500],
    'colsample_bytree': [0.4, 0.8]
}

# inner loop 
inner_cv = GroupKFold(n_splits=5)
inner_cv = inner_cv.get_n_splits(X_values, y, groups=family_groups)

# outer loop
outer_cv = GroupKFold(n_splits=5)
outer_cv = outer_cv.get_n_splits(X_values, y, groups=family_groups)
  
# inner loop grid search
gs = GridSearchCV(
    estimator=model, 
    param_grid=params, 
    scoring='roc_auc', 
    cv=inner_cv,
    return_train_score=True,
    verbose=3
)
gs.fit(X_values, y)

# multiple metrics 
scoring = ['roc_auc', 'accuracy', 'precision', 'recall', 'f1']

# outer loop scores 
nested_scores = cross_validate(
    gs,
    X=X_values, 
    y=y, 
    scoring=scoring, 
    cv=outer_cv,
)

# obtain model scores from outer folds
y_scores = cross_val_predict(
    gs, 
    X_values, 
    y, 
    cv=outer_cv, 
    method='predict_proba',           
)[:, 1]
df_scores = pd.DataFrame({'y_true': y, 'y_scores': y_scores})
df_scores.to_csv(f'demographics_y_true_y_scores.csv', index=False)

auc = nested_scores['test_roc_auc']
acc = nested_scores['test_accuracy']
precision = nested_scores['test_precision']
recall = nested_scores['test_recall']
f1 = nested_scores['test_f1']
print('='*120)
print('\nRuntime:', str(timedelta(seconds=time()-start_time)))
print()
print(f'Average ROC AUC score:      {auc.mean():.4f} {auc}')
print(f'Average accuracy score:     {acc.mean():.4f} {acc}')
print(f'Average precision score:    {precision.mean():.4f} {precision}')
print(f'Average recall score:       {recall.mean():.4f} {recall}')
print(f'Average F1 score:           {f1.mean():.4f} {f1}')
print('\nBest parameters:\n', gs.best_params_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.700, test=0.668) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.695, test=0.685) total time=   0.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.689, test=0.687) total time=   0.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.698, test=0.663) total time=   0.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.693, test=0.690) total time=   0.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.709, test=0.673) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.704, test=0.683) total time=   0.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.700, test=0.693) total time=   0.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.707, test=0.668) total time=   0.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.704, test=0.700) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.715, test=0.676) total time=   1.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.710, test=0.687) total time=   0.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.705, test=0.696) total time=   0.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.714, test=0.677) total time=   1.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.709, test=0.701) total time=   1.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.718, test=0.677) total time=   1.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.714, test=0.689) total time=   1.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.709, test=0.697) total time=   1.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.717, test=0.679) total time=   1.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.712, test=0.699) total time=   1.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.721, test=0.677) total time=   2.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.717, test=0.689) total time=   2.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.711, test=0.698) total time=   2.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.719, test=0.679) total time=   2.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.715, test=0.697) total time=   2.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.723, test=0.676) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.719, test=0.687) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.714, test=0.699) total time=   3.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.721, test=0.680) total time=   2.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.717, test=0.696) total time=   3.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.708, test=0.671) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.702, test=0.690) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.699, test=0.689) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.706, test=0.671) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.704, test=0.694) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.717, test=0.676) total time=   0.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.713, test=0.693) total time=   0.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.709, test=0.699) total time=   0.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.715, test=0.680) total time=   0.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.713, test=0.700) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.722, test=0.677) total time=   1.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.719, test=0.690) total time=   1.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.714, test=0.699) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.720, test=0.681) total time=   1.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.718, test=0.698) total time=   1.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.726, test=0.676) total time=   2.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.722, test=0.689) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.717, test=0.700) total time=   2.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.724, test=0.679) total time=   2.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.721, test=0.697) total time=   2.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.730, test=0.675) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.727, test=0.688) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.719, test=0.700) total time=   2.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.726, test=0.679) total time=   2.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.724, test=0.694) total time=   2.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.732, test=0.674) total time=   3.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.729, test=0.686) total time=   3.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.722, test=0.700) total time=   3.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.729, test=0.679) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.726, test=0.694) total time=   3.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.712, test=0.670) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.705, test=0.691) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.704, test=0.692) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.709, test=0.675) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.707, test=0.692) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.721, test=0.676) total time=   0.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.717, test=0.693) total time=   0.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.713, test=0.697) total time=   0.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.718, test=0.681) total time=   0.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.716, test=0.698) total time=   0.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.726, test=0.675) total time=   1.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.723, test=0.690) total time=   1.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.718, test=0.699) total time=   1.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.724, test=0.680) total time=   1.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.722, test=0.695) total time=   1.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=0.730, test=0.676) total time=   2.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=0.728, test=0.688) total time=   2.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=0.721, test=0.700) total time=   2.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=0.727, test=0.679) total time=   2.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=0.725, test=0.694) total time=   2.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=0.734, test=0.675) total time=   3.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=0.731, test=0.686) total time=   3.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=0.724, test=0.700) total time=   3.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=0.730, test=0.679) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=0.727, test=0.693) total time=   3.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=0.737, test=0.674) total time=   4.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=0.733, test=0.685) total time=   4.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=0.726, test=0.700) total time=   4.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=0.733, test=0.681) total time=   4.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=0.730, test=0.692) total time=   4.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.701, test=0.668) total time=   0.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.696, test=0.686) total time=   0.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.691, test=0.688) total time=   0.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.699, test=0.665) total time=   0.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.696, test=0.693) total time=   0.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.715, test=0.676) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.710, test=0.687) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.705, test=0.697) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.713, test=0.676) total time=   0.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.709, test=0.701) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.721, test=0.678) total time=   1.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.718, test=0.690) total time=   1.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.712, test=0.699) total time=   1.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.718, test=0.677) total time=   1.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.715, test=0.697) total time=   1.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.726, test=0.676) total time=   1.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.723, test=0.686) total time=   1.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.716, test=0.701) total time=   1.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.723, test=0.679) total time=   1.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.719, test=0.695) total time=   1.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.729, test=0.674) total time=   2.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.726, test=0.684) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.719, test=0.700) total time=   2.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.726, test=0.678) total time=   2.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.723, test=0.693) total time=   2.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.731, test=0.673) total time=   2.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.729, test=0.682) total time=   2.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.721, test=0.700) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.728, test=0.677) total time=   2.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.726, test=0.692) total time=   2.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.710, test=0.671) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.705, test=0.691) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.700, test=0.690) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.707, test=0.672) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.705, test=0.694) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.723, test=0.677) total time=   0.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.719, test=0.690) total time=   0.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.714, test=0.699) total time=   0.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.720, test=0.680) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.718, test=0.697) total time=   0.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.729, test=0.675) total time=   1.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.726, test=0.687) total time=   1.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.719, test=0.701) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.726, test=0.679) total time=   1.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.723, test=0.694) total time=   1.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=0.734, test=0.674) total time=   2.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=0.731, test=0.685) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=0.724, test=0.701) total time=   2.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=0.731, test=0.679) total time=   2.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=0.728, test=0.693) total time=   2.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=0.738, test=0.673) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=0.734, test=0.682) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=0.727, test=0.699) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=0.734, test=0.679) total time=   2.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=0.731, test=0.691) total time=   2.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=0.740, test=0.673) total time=   3.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=0.736, test=0.681) total time=   3.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=0.729, test=0.699) total time=   3.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=0.736, test=0.679) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=0.732, test=0.691) total time=   3.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.714, test=0.671) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.709, test=0.690) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.706, test=0.693) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.711, test=0.675) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.709, test=0.693) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=0.727, test=0.675) total time=   0.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=0.723, test=0.690) total time=   0.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=0.718, test=0.699) total time=   0.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=0.724, test=0.681) total time=   0.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=0.722, test=0.695) total time=   0.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.734, test=0.674) total time=   1.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.730, test=0.686) total time=   1.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.724, test=0.700) total time=   1.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.730, test=0.679) total time=   1.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.728, test=0.693) total time=   1.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.739, test=0.674) total time=   2.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.735, test=0.683) total time=   2.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.728, test=0.699) total time=   2.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.735, test=0.680) total time=   2.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.731, test=0.691) total time=   2.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.742, test=0.672) total time=   3.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.737, test=0.681) total time=   3.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.731, test=0.697) total time=   3.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.737, test=0.679) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.734, test=0.689) total time=   3.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.744, test=0.671) total time=   4.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.739, test=0.679) total time=   4.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.733, test=0.697) total time=   4.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.739, test=0.679) total time=   4.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.735, test=0.690) total time=   4.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.720, test=0.676) total time=   0.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.716, test=0.685) total time=   0.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.711, test=0.701) total time=   0.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.719, test=0.678) total time=   0.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.714, test=0.698) total time=   0.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.739, test=0.671) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.735, test=0.681) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.728, test=0.699) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.736, test=0.679) total time=   0.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.732, test=0.692) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.744, test=0.668) total time=   1.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.739, test=0.676) total time=   1.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.733, test=0.696) total time=   1.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.739, test=0.677) total time=   1.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.736, test=0.688) total time=   1.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.747, test=0.666) total time=   1.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.742, test=0.674) total time=   1.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.737, test=0.696) total time=   1.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.742, test=0.677) total time=   1.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.739, test=0.688) total time=   1.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.749, test=0.664) total time=   2.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.743, test=0.672) total time=   2.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.738, test=0.695) total time=   2.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.744, test=0.676) total time=   2.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.741, test=0.688) total time=   2.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.751, test=0.663) total time=   2.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.745, test=0.669) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.740, test=0.694) total time=   2.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.745, test=0.675) total time=   2.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.743, test=0.685) total time=   2.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.730, test=0.675) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.726, test=0.686) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.719, test=0.700) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.726, test=0.677) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.723, test=0.695) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.746, test=0.669) total time=   0.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.741, test=0.675) total time=   0.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.735, test=0.697) total time=   0.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.741, test=0.677) total time=   0.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.738, test=0.690) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.750, test=0.664) total time=   1.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.745, test=0.671) total time=   1.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.740, test=0.697) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.744, test=0.675) total time=   1.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.742, test=0.685) total time=   1.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.752, test=0.663) total time=   2.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.747, test=0.666) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.742, test=0.695) total time=   2.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.747, test=0.673) total time=   2.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.745, test=0.683) total time=   2.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.754, test=0.662) total time=   2.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.749, test=0.663) total time=   2.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.744, test=0.694) total time=   2.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.748, test=0.673) total time=   2.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.746, test=0.681) total time=   2.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.755, test=0.660) total time=   3.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.750, test=0.661) total time=   3.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.745, test=0.693) total time=   3.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.750, test=0.673) total time=   3.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.748, test=0.680) total time=   3.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.734, test=0.676) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.730, test=0.686) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.724, test=0.700) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.731, test=0.680) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.728, test=0.690) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.749, test=0.666) total time=   0.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.743, test=0.673) total time=   0.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.738, test=0.695) total time=   0.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.743, test=0.675) total time=   0.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.740, test=0.686) total time=   0.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.753, test=0.663) total time=   1.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.747, test=0.669) total time=   1.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.742, test=0.694) total time=   1.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.747, test=0.674) total time=   1.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.745, test=0.682) total time=   1.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.755, test=0.661) total time=   2.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.750, test=0.664) total time=   2.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.745, test=0.693) total time=   2.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.749, test=0.673) total time=   2.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.747, test=0.680) total time=   2.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.756, test=0.660) total time=   3.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.751, test=0.662) total time=   3.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.746, test=0.693) total time=   3.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.751, test=0.671) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.749, test=0.678) total time=   3.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.757, test=0.659) total time=   4.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.753, test=0.660) total time=   4.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.748, test=0.692) total time=   4.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.752, test=0.670) total time=   4.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.750, test=0.677) total time=   4.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.691, test=0.663) total time=   0.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.691, test=0.665) total time=   0.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.682, test=0.668) total time=   0.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.693, test=0.648) total time=   0.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.685, test=0.682) total time=   0.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.706, test=0.674) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.701, test=0.678) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.697, test=0.693) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.703, test=0.661) total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.699, test=0.696) total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.715, test=0.673) total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.710, test=0.682) total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.706, test=0.695) total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.712, test=0.672) total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.708, test=0.698) total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.720, test=0.675) total time=   1.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.717, test=0.682) total time=   1.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.711, test=0.699) total time=   1.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.717, test=0.674) total time=   1.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.714, test=0.696) total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.724, test=0.675) total time=   2.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.720, test=0.683) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.714, test=0.698) total time=   2.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.720, test=0.675) total time=   2.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.717, test=0.696) total time=   2.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.727, test=0.676) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.724, test=0.681) total time=   2.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.716, test=0.699) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.723, test=0.676) total time=   2.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.720, test=0.696) total time=   2.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.712, test=0.672) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.707, test=0.672) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.701, test=0.690) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.709, test=0.663) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.706, test=0.697) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.720, test=0.675) total time=   0.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.716, test=0.677) total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.710, test=0.698) total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.716, test=0.676) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.715, test=0.698) total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.726, test=0.673) total time=   1.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.723, test=0.682) total time=   1.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.717, test=0.701) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.722, test=0.677) total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.721, test=0.698) total time=   1.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.732, test=0.673) total time=   2.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.728, test=0.684) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.722, test=0.700) total time=   2.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.727, test=0.678) total time=   2.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.725, test=0.697) total time=   2.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.736, test=0.673) total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.732, test=0.683) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.724, test=0.700) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.731, test=0.678) total time=   2.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.728, test=0.695) total time=   2.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.738, test=0.673) total time=   3.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.734, test=0.680) total time=   3.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.727, test=0.700) total time=   3.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.733, test=0.680) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=0.731, test=0.694) total time=   3.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.720, test=0.676) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.718, test=0.681) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.710, test=0.700) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.717, test=0.672) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.715, test=0.697) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.728, test=0.676) total time=   0.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.724, test=0.684) total time=   0.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.718, test=0.701) total time=   0.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.724, test=0.679) total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.723, test=0.699) total time=   0.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.733, test=0.675) total time=   1.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.730, test=0.684) total time=   1.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.723, test=0.700) total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.729, test=0.680) total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=0.727, test=0.696) total time=   1.8s
# ...
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=0.728, test=0.685) total time=   0.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.745, test=0.666) total time=   1.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.739, test=0.686) total time=   1.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.739, test=0.681) total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.736, test=0.683) total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=0.736, test=0.688) total time=   1.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.750, test=0.660) total time=   2.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.743, test=0.682) total time=   2.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.743, test=0.679) total time=   2.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.741, test=0.684) total time=   2.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=0.740, test=0.686) total time=   2.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.753, test=0.656) total time=   3.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.745, test=0.678) total time=   3.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.746, test=0.674) total time=   3.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.743, test=0.682) total time=   3.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=0.743, test=0.684) total time=   3.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.755, test=0.653) total time=   4.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.747, test=0.677) total time=   4.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.747, test=0.672) total time=   4.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.746, test=0.679) total time=   4.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=0.745, test=0.683) total time=   4.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.726, test=0.676) total time=   0.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.721, test=0.684) total time=   0.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.721, test=0.689) total time=   0.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.720, test=0.683) total time=   0.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.719, test=0.681) total time=   0.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.747, test=0.664) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.741, test=0.678) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.742, test=0.680) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.736, test=0.677) total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=0.738, test=0.684) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.752, test=0.660) total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.744, test=0.677) total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.747, test=0.673) total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.743, test=0.680) total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=0.742, test=0.684) total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.755, test=0.657) total time=   1.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.748, test=0.675) total time=   1.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.749, test=0.672) total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.746, test=0.680) total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=0.746, test=0.684) total time=   1.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.757, test=0.654) total time=   2.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.750, test=0.675) total time=   2.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.751, test=0.670) total time=   2.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.749, test=0.679) total time=   2.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=0.748, test=0.683) total time=   2.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.759, test=0.652) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.751, test=0.676) total time=   3.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.752, test=0.671) total time=   3.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.751, test=0.678) total time=   3.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=0.749, test=0.682) total time=   2.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.739, test=0.671) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.733, test=0.685) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.732, test=0.680) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.731, test=0.684) total time=   0.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.729, test=0.685) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.756, test=0.652) total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.748, test=0.675) total time=   0.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.749, test=0.671) total time=   0.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.747, test=0.680) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=0.745, test=0.684) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.761, test=0.647) total time=   1.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.753, test=0.674) total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.753, test=0.670) total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.753, test=0.676) total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=0.750, test=0.683) total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.763, test=0.645) total time=   2.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.755, test=0.673) total time=   2.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.755, test=0.668) total time=   2.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.756, test=0.676) total time=   2.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=0.753, test=0.682) total time=   2.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.764, test=0.643) total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.757, test=0.672) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.756, test=0.667) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.757, test=0.675) total time=   2.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=0.755, test=0.680) total time=   2.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.766, test=0.641) total time=   3.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.758, test=0.670) total time=   3.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.757, test=0.666) total time=   3.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.759, test=0.673) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=0.756, test=0.677) total time=   3.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.745, test=0.664) total time=   0.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.738, test=0.685) total time=   0.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.739, test=0.682) total time=   0.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.737, test=0.684) total time=   0.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=0.736, test=0.688) total time=   0.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.760, test=0.649) total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.752, test=0.675) total time=   0.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.751, test=0.670) total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.752, test=0.677) total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=0.749, test=0.683) total time=   0.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.763, test=0.645) total time=   1.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.756, test=0.672) total time=   1.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.755, test=0.666) total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.757, test=0.675) total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=0.754, test=0.681) total time=   1.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.765, test=0.642) total time=   2.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.759, test=0.670) total time=   2.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.757, test=0.665) total time=   2.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.759, test=0.673) total time=   2.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=0.756, test=0.678) total time=   2.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.767, test=0.639) total time=   3.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.760, test=0.669) total time=   3.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.759, test=0.663) total time=   3.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.760, test=0.670) total time=   3.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=0.757, test=0.675) total time=   3.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.768, test=0.639) total time=   4.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.761, test=0.668) total time=   4.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.759, test=0.662) total time=   4.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.760, test=0.669) total time=   4.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=0.757, test=0.675) total time=   4.4s
# ========================================================================================================================
#
# Runtime: 3:12:22.717635
#
# Average ROC AUC score:      0.6887 [0.67744843 0.69026511 0.69891858 0.68146082 0.69545356]
# Average accuracy score:     0.8598 [0.85994398 0.85994398 0.86034563 0.86034563 0.85847735]
# Average precision score:    0.0000 [0. 0. 0. 0. 0.]
# Average recall score:       0.0000 [0. 0. 0. 0. 0.]
# Average F1 score:           0.0000 [0. 0. 0. 0. 0.]
#
# Best parameters:
#  {'colsample_bytree': 0.4, 'learning_rate': 0.005, 'max_depth': 6, 'n_estimators': 500}

# %%
joblib.dump(gs, 'demographics_gridsearch.pkl')
joblib.dump(nested_scores, 'demographics_nested_scores.pkl')
# Out:
# ['demographics_nested_scores.pkl']

# %% [markdown]
# # SHAP (SHapley Additive exPlanations)

# %%
explainer = shap.Explainer(gs.best_estimator_)
shap_values = explainer(X)

# %% [markdown]
# # SHAP ranking of top model features

# %%
# Create SHAP ranking dataframe
sv_mean = np.abs(shap_values.values).mean(0)
sv_rank = pd.DataFrame(list(zip(X, sv_mean)), columns=['feature', 'mean absolute SHAP value'])
sv_rank = sv_rank.sort_values(by='mean absolute SHAP value', ascending=False)
sv_rank['percent importance'] = sv_rank['mean absolute SHAP value'] / sv_rank['mean absolute SHAP value'].sum()*100
sv_rank['cumulative importance (%)'] = sv_rank['percent importance'].cumsum()
sv_rank.reset_index(inplace=True, drop=True)
sv_rank.to_csv(f'demographics_shap_ranking.csv', index=False)

pd.options.display.max_rows = None
print(f"Sum of SHAP values: {sv_rank['mean absolute SHAP value'].sum()}")
sv_rank[:20]
# Out:
# Sum of SHAP values: 0.7658640742301941
#                                     feature  mean absolute SHAP value  \
# 0   meim_ethnic_id_p_black/african_american                  0.133206
# 1                          site_id_l_site16                  0.123752
# 2          meim_ethnic_id_p_white/caucasian                  0.093740
# 3                          demo_sex_v2_male                  0.070782
# 4          meim_ethnic_id_p_hispanic/latino                  0.049348
# 5                          site_id_l_site08                  0.033824
# 6                          site_id_l_site02                  0.030905
# 7                          site_id_l_site18                  0.028265
# 8                          site_id_l_site06                  0.027476
# 9                          site_id_l_site14                  0.026694
# 10                         site_id_l_site15                  0.024590
# 11                         site_id_l_site10                  0.024351
# 12                         site_id_l_site01                  0.010126
# 13                   meim_ethnic_id_p_mixed                  0.009837
# 14                         site_id_l_site03                  0.008872
# 15                         site_id_l_site07                  0.007864
# 16                         site_id_l_site17                  0.007768
# 17                         site_id_l_site19                  0.007152
# 18        meim_ethnic_id_p_western_european                  0.006882
# 19                         site_id_l_site20                  0.006861
#
#     percent importance  cumulative importance (%)
# 0            17.392931                  17.392931
# 1            16.158535                  33.551468
# 2            12.239744                  45.791214
# 3             9.242085                  55.033298
# 4             6.443430                  61.476730
# 5             4.416409                  65.893143
# 6             4.035327                  69.928467
# 7             3.690638                  73.619102
# 8             3.587623                  77.206726
# 9             3.485539                  80.692268
# 10            3.210754                  83.903023
# 11            3.179577                  87.082603
# 12            1.322190                  88.404793
# 13            1.284485                  89.689278
# 14            1.158395                  90.847672
# 15            1.026879                  91.874550
# 16            1.014340                  92.888893
# 17            0.933802                  93.822693
# 18            0.898615                  94.721306
# 19            0.895800                  95.617104

# %% [markdown]
# # SHAP summary plot of top features

# %%
shap.plots.beeswarm(shap_values, max_display=21)

# %% [markdown]
# # SHAP dependence plots

# %%
top_inds = np.argsort(-np.sum(np.abs(shap_values.values), 0))
for i in range(20):
    shap.plots.scatter(shap_values[:, top_inds[i]], color=shap_values)
