# %%
import pandas as pd
import numpy as np
import shap
import warnings
import joblib
import sys
import psutil
import GPUtil
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, cross_validate, GroupKFold, cross_val_predict, ParameterGrid
from collections import defaultdict
from time import time
from datetime import timedelta
from importlib.metadata import version

# printout of python version
print("="*50, "Python Version", "="*50)
print(f"python version: {sys.version}")
print(f"xgboost:        {version('xgboost')}")
print(f"shap:           {version('shap')}")

# printout of hardware
print("="*50, "Hardware", "="*50)
gpus = GPUtil.getGPUs()
for gpu in gpus:
    print(f"GPU: {gpu.name}")
print(f"CPU cores: {psutil.cpu_count(logical=False)}")
print(f"RAM: {psutil.virtual_memory().total / 1024 / 1024 / 1024 :.2f} GB")

warnings.filterwarnings('ignore')
# Out:
# ================================================== Python Version ==================================================
# python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]
# xgboost:        2.1.1
# shap:           0.46.0
# ================================================== Hardware ==================================================
# GPU: NVIDIA GeForce RTX 4090
# CPU cores: 16
# RAM: 63.82 GB

# %% [markdown]
# # read data function

# %%
def read_abcd(path, cols, na_values):
    
    df = pd.read_csv(path, sep='\t', index_col='subjectkey', na_values=na_values)
    df = df.drop(df.index[0])
    
    for col in cols:
        df[col] = pd.to_numeric(df[col])
        df = df[cols]

    df = df.reset_index()
    df = df.sort_values(['subjectkey', 'interview_age'])
    df = df.drop_duplicates(subset=['subjectkey'], keep='first')
    df = df.drop(columns=['interview_age'])
    df = df.set_index('subjectkey')
    
    df_show = abcd_ysu02.join(df)
    df_show = df_show.drop(columns=[
        'isip_1d_2',
        'isip_5_2',
        'isip_1b_yn'
    ])
     
    for col in df_show.columns:
        print('{:<30}    n = {:<10}    mean = {:<10.4f}    sum = {:<10.1f}'.\
              format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
    print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
    
    return df

# %% [markdown]
# # y-target variable

# %%
file_abcd_ysu02 = r'D:\gregn\data\ABCD\abcd3\abcd_ysu02.txt'
abcd_ysu02 = pd.read_csv(file_abcd_ysu02, sep='\t', index_col='subjectkey')
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02.index[0])
cols = [
    'interview_age',
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
]

for col in cols:
    abcd_ysu02[col] = pd.to_numeric(abcd_ysu02[col])
    abcd_ysu02 = abcd_ysu02[cols]
    
abcd_ysu02 = abcd_ysu02.reset_index()
abcd_ysu02 = abcd_ysu02.sort_values(['subjectkey', 'interview_age'])
abcd_ysu02 = abcd_ysu02.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_ysu02 = abcd_ysu02.drop(columns=['interview_age'])
abcd_ysu02 = abcd_ysu02.set_index('subjectkey')
    
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_5_2 == 3].index) # drop accidental 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_5_2 == 2].index) # drop furtive 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_1b_yn == 0].index) # drop religious 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_1d_2 > 10].index) # drop older than 10

abcd_ysu02['isip_1d_2'] = abcd_ysu02['isip_1d_2'].fillna(0)

y = abcd_ysu02['isip_1d_2'].values
y = np.where(y>0, 1, y)

unique, counts = np.unique(y, return_counts=True)

print('number of subjects: {:>10}\n\n[0] never sipped: {:>12}\n[1] sipped by age 10:{:>9}'.\
      format(len(y), counts[0], counts[1]))
# Out:
# number of subjects:      10707
#
# [0] never sipped:         9209
# [1] sipped by age 10:     1498

# %% [markdown]
# # acspsw03

# %%
path = r'D:\gregn\data\ABCD\abcd3\acspsw03.txt'

cols = [
    'interview_age',
    'rel_family_id',
]

na_values = [None]
acspsw03 = read_abcd(path, cols, na_values)
# Out:
# rel_family_id                     n = 10707         mean = 5921.1416     sum = 63397663.0
#
# subjects:     10707
# features:         1

# %% [markdown]
# # load X feature datasets

# %%
env = pd.read_csv(r'C:\Users\gregn\jupyter\ABCD_sipping_paper\environmental\X_features_environmental.csv')
psych = pd.read_csv(r'C:\Users\gregn\jupyter\ABCD_sipping_paper\psychological\X_features_psychological.csv')
health = pd.read_csv(r'C:\Users\gregn\jupyter\ABCD_sipping_paper\health\X_features_health.csv')

abcd = pd.merge(env, psych, on='subjectkey', how='left')
abcd = pd.merge(abcd, health, on='subjectkey', how='left')
abcd = pd.merge(abcd, acspsw03, on='subjectkey', how='left')
X = abcd.drop(columns=['subjectkey', 'rel_family_id'])
X_values = X.values

# %% [markdown]
# # family groups

# %%
d = defaultdict(lambda: len(d))
family_groups = [d[x] for x in abcd['rel_family_id']]
family_groups = np.array(family_groups)
print(f"there are {len(np.unique(family_groups))} unique family groups")
# Out:
# there are 9011 unique family groups

# %% [markdown]
# # XGBoost: 5x5 nested cross validation

# %%
start_time = time()

model = XGBClassifier(
    tree_method = 'gpu_hist',
    objective = 'binary:logistic',
    eval_metric = 'auc',
    random_state = 42, 
)

# hyperparameter grid
params = {
    'learning_rate': [0.005, 0.01, 0.1],
    'max_depth': [4, 6, 8],
    'n_estimators': [100, 500, 1000, 1500, 2000, 2500],
    'colsample_bytree': [0.4, 0.8]
}

# inner loop 
inner_cv = GroupKFold(n_splits=5)
inner_cv = inner_cv.get_n_splits(X_values, y, groups=family_groups)

# outer loop
outer_cv = GroupKFold(n_splits=5)
outer_cv = outer_cv.get_n_splits(X_values, y, groups=family_groups)
  
# inner loop grid search
gs = GridSearchCV(
    estimator=model, 
    param_grid=params, 
    scoring='roc_auc', 
    cv=inner_cv,
    return_train_score=True,
    verbose=3
)
gs.fit(X_values, y)

# multiple metrics 
scoring = ['roc_auc', 'accuracy', 'precision', 'recall', 'f1']

# outer loop scores 
nested_scores = cross_validate(
    gs,
    X=X_values, 
    y=y, 
    scoring=scoring, 
    cv=outer_cv,
)

# obtain model scores from outer folds
y_scores = cross_val_predict(
    gs, 
    X_values, 
    y, 
    cv=outer_cv, 
    method='predict_proba',           
)[:, 1]
df_scores = pd.DataFrame({'y_true': y, 'y_scores': y_scores})
df_scores.to_csv(f'multimodal_y_true_y_scores.csv', index=False)

auc = nested_scores['test_roc_auc']
acc = nested_scores['test_accuracy']
precision = nested_scores['test_precision']
recall = nested_scores['test_recall']
f1 = nested_scores['test_f1']
print('='*120)
print('\nRuntime:', str(timedelta(seconds=time()-start_time)))
print()
print(f'Average ROC AUC score:      {auc.mean():.4f} {auc}')
print(f'Average accuracy score:     {acc.mean():.4f} {acc}')
print(f'Average precision score:    {precision.mean():.4f} {precision}')
print(f'Average recall score:       {recall.mean():.4f} {recall}')
print(f'Average F1 score:           {f1.mean():.4f} {f1}')
print('\nBest parameters:\n', gs.best_params_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.811, test=0.755) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.808, test=0.754) total time=   0.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.807, test=0.737) total time=   0.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.812, test=0.728) total time=   0.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.810, test=0.744) total time=   0.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.853, test=0.765) total time=   1.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.852, test=0.772) total time=   1.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.855, test=0.760) total time=   1.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.857, test=0.746) total time=   1.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.854, test=0.755) total time=   1.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.893, test=0.770) total time=   2.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.891, test=0.778) total time=   2.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.898, test=0.766) total time=   2.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.896, test=0.753) total time=   2.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.895, test=0.765) total time=   2.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.925, test=0.771) total time=   3.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.921, test=0.777) total time=   3.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.926, test=0.766) total time=   3.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.926, test=0.752) total time=   3.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.924, test=0.767) total time=   3.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.945, test=0.771) total time=   4.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.942, test=0.776) total time=   4.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.948, test=0.766) total time=   3.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.947, test=0.752) total time=   4.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.945, test=0.768) total time=   4.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.960, test=0.770) total time=   4.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.957, test=0.776) total time=   4.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.964, test=0.765) total time=   4.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.962, test=0.752) total time=   5.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.961, test=0.768) total time=   5.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.914, test=0.765) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.907, test=0.765) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.912, test=0.747) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.912, test=0.734) total time=   0.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.912, test=0.755) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.965, test=0.768) total time=   1.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.962, test=0.779) total time=   1.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.966, test=0.765) total time=   1.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.965, test=0.751) total time=   1.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.963, test=0.762) total time=   1.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.989, test=0.770) total time=   3.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.987, test=0.779) total time=   3.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.990, test=0.767) total time=   3.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.989, test=0.753) total time=   3.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.988, test=0.769) total time=   3.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.769) total time=   4.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.778) total time=   4.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.765) total time=   4.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.997, test=0.753) total time=   4.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.772) total time=   4.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.768) total time=   5.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.776) total time=   5.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.764) total time=   5.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.752) total time=   5.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.772) total time=   5.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.767) total time=   6.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.775) total time=   6.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.762) total time=   6.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.752) total time=   6.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.772) total time=   7.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.985, test=0.767) total time=   0.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.982, test=0.768) total time=   0.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.987, test=0.753) total time=   0.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.983, test=0.734) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.983, test=0.759) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.999, test=0.768) total time=   2.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.999, test=0.777) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.999, test=0.765) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.999, test=0.750) total time=   2.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.999, test=0.766) total time=   2.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.768) total time=   4.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.779) total time=   4.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.767) total time=   4.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.751) total time=   4.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.771) total time=   4.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.768) total time=   6.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.778) total time=   6.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.766) total time=   6.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.751) total time=   6.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.773) total time=   6.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.767) total time=   8.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.776) total time=   8.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.765) total time=   8.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.751) total time=   8.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.774) total time=   8.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.767) total time=  10.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.776) total time=  10.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.764) total time=  10.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.749) total time=  10.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.775) total time=  10.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.823, test=0.758) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.820, test=0.763) total time=   0.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.821, test=0.747) total time=   0.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.825, test=0.735) total time=   0.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100;, score=(train=0.823, test=0.747) total time=   0.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.893, test=0.768) total time=   1.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.890, test=0.777) total time=   1.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.898, test=0.764) total time=   1.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.895, test=0.754) total time=   1.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500;, score=(train=0.895, test=0.766) total time=   1.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.945, test=0.771) total time=   2.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.941, test=0.775) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.949, test=0.765) total time=   2.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.946, test=0.752) total time=   2.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000;, score=(train=0.945, test=0.769) total time=   2.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.971, test=0.769) total time=   3.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.970, test=0.776) total time=   3.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.975, test=0.765) total time=   3.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.973, test=0.751) total time=   3.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500;, score=(train=0.973, test=0.772) total time=   3.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.985, test=0.767) total time=   3.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.985, test=0.774) total time=   3.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.988, test=0.762) total time=   3.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.987, test=0.752) total time=   4.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000;, score=(train=0.987, test=0.771) total time=   4.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.993, test=0.764) total time=   4.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.993, test=0.773) total time=   4.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.995, test=0.760) total time=   4.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.995, test=0.750) total time=   5.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500;, score=(train=0.994, test=0.770) total time=   4.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.929, test=0.766) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.922, test=0.770) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.927, test=0.754) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.931, test=0.742) total time=   0.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100;, score=(train=0.927, test=0.757) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.989, test=0.770) total time=   1.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.985, test=0.776) total time=   1.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.990, test=0.769) total time=   1.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.989, test=0.754) total time=   1.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500;, score=(train=0.988, test=0.769) total time=   1.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.999, test=0.768) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.999, test=0.774) total time=   2.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.999, test=0.765) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.999, test=0.753) total time=   2.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000;, score=(train=0.999, test=0.771) total time=   2.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.767) total time=   4.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.773) total time=   4.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.763) total time=   4.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.750) total time=   4.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.770) total time=   4.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.764) total time=   5.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.773) total time=   5.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.759) total time=   5.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.749) total time=   5.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.770) total time=   5.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.764) total time=   6.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.774) total time=   6.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.757) total time=   6.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.748) total time=   6.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.769) total time=   7.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.991, test=0.765) total time=   0.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.988, test=0.769) total time=   0.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.992, test=0.757) total time=   0.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.991, test=0.745) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100;, score=(train=0.992, test=0.761) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.764) total time=   2.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.778) total time=   2.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.769) total time=   2.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.754) total time=   2.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.769) total time=   2.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.764) total time=   4.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.778) total time=   4.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.766) total time=   4.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.752) total time=   4.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.771) total time=   4.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.764) total time=   6.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.777) total time=   6.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.763) total time=   6.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.751) total time=   6.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.772) total time=   6.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.762) total time=   8.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.777) total time=   8.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.762) total time=   8.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.751) total time=   8.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.772) total time=   8.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.762) total time=  10.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.776) total time=  10.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.761) total time=  10.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.750) total time=  10.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.771) total time=  10.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.945, test=0.766) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.939, test=0.780) total time=   0.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.946, test=0.756) total time=   0.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.946, test=0.751) total time=   0.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.945, test=0.761) total time=   0.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.756) total time=   1.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.767) total time=   1.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.749) total time=   1.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.740) total time=   1.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.758) total time=   1.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.755) total time=   2.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.763) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.739) total time=   2.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.727) total time=   2.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.755) total time=   2.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.753) total time=   3.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.756) total time=   3.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.739) total time=   3.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.724) total time=   3.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.756) total time=   2.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.751) total time=   3.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.755) total time=   3.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.738) total time=   3.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.723) total time=   4.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.754) total time=   4.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.748) total time=   5.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.754) total time=   4.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.737) total time=   4.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.721) total time=   5.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.754) total time=   4.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.998, test=0.759) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.998, test=0.772) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.999, test=0.753) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.999, test=0.744) total time=   0.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=0.998, test=0.765) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.754) total time=   1.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.765) total time=   1.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.751) total time=   1.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.733) total time=   1.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.764) total time=   1.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.753) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.761) total time=   2.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.749) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.730) total time=   2.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.760) total time=   2.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.751) total time=   4.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.760) total time=   4.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.746) total time=   4.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.728) total time=   4.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.760) total time=   4.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.749) total time=   5.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.759) total time=   5.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.745) total time=   5.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.727) total time=   5.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.759) total time=   5.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.749) total time=   6.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.758) total time=   6.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.745) total time=   6.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.725) total time=   6.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.760) total time=   6.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.760) total time=   0.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.762) total time=   0.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.745) total time=   0.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.740) total time=   0.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.758) total time=   0.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.762) total time=   2.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.760) total time=   2.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.745) total time=   2.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.742) total time=   2.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.763) total time=   2.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.758) total time=   3.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.760) total time=   3.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.744) total time=   3.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.738) total time=   3.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.762) total time=   3.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.757) total time=   5.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.758) total time=   5.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.743) total time=   5.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.735) total time=   5.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.762) total time=   5.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.756) total time=   6.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.758) total time=   6.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.743) total time=   6.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.733) total time=   6.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.762) total time=   6.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.756) total time=   7.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.757) total time=   7.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.742) total time=   7.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.731) total time=   7.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.761) total time=   7.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.792, test=0.734) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.790, test=0.758) total time=   0.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.786, test=0.725) total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.793, test=0.715) total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100;, score=(train=0.794, test=0.723) total time=   0.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.848, test=0.760) total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.849, test=0.777) total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.851, test=0.757) total time=   1.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.854, test=0.744) total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500;, score=(train=0.851, test=0.751) total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.895, test=0.767) total time=   2.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.897, test=0.779) total time=   2.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.904, test=0.760) total time=   2.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.899, test=0.751) total time=   2.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000;, score=(train=0.900, test=0.764) total time=   2.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.928, test=0.769) total time=   3.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.927, test=0.778) total time=   3.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.931, test=0.760) total time=   3.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.930, test=0.749) total time=   3.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500;, score=(train=0.929, test=0.766) total time=   3.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.948, test=0.769) total time=   4.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.947, test=0.777) total time=   4.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.953, test=0.761) total time=   4.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.951, test=0.750) total time=   4.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000;, score=(train=0.951, test=0.766) total time=   4.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.963, test=0.767) total time=   4.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.963, test=0.776) total time=   5.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.968, test=0.760) total time=   5.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.966, test=0.749) total time=   5.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500;, score=(train=0.966, test=0.766) total time=   5.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.898, test=0.742) total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.891, test=0.760) total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.891, test=0.735) total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.894, test=0.718) total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100;, score=(train=0.891, test=0.734) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.958, test=0.761) total time=   1.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.954, test=0.776) total time=   1.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.956, test=0.762) total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.957, test=0.744) total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500;, score=(train=0.953, test=0.757) total time=   1.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.987, test=0.764) total time=   3.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.987, test=0.775) total time=   3.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.989, test=0.763) total time=   3.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.989, test=0.748) total time=   3.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000;, score=(train=0.987, test=0.767) total time=   3.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.765) total time=   4.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.774) total time=   4.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.763) total time=   4.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.997, test=0.746) total time=   4.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500;, score=(train=0.996, test=0.769) total time=   4.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.763) total time=   5.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.772) total time=   6.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.762) total time=   5.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.747) total time=   6.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000;, score=(train=0.999, test=0.769) total time=   6.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.762) total time=   7.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.771) total time=   7.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.760) total time=   7.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.747) total time=   7.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.768) total time=   7.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.974, test=0.740) total time=   0.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.966, test=0.765) total time=   0.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.977, test=0.731) total time=   0.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.973, test=0.726) total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100;, score=(train=0.966, test=0.743) total time=   0.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.998, test=0.758) total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.997, test=0.775) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.998, test=0.762) total time=   2.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.998, test=0.745) total time=   2.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500;, score=(train=0.997, test=0.763) total time=   2.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.765) total time=   5.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.777) total time=   4.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.762) total time=   5.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.748) total time=   5.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.770) total time=   5.1s
# ...
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.776) total time=   4.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.755) total time=   4.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.784) total time=   4.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.732) total time=   4.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.761) total time=   4.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.777) total time=   6.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.755) total time=   6.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.781) total time=   6.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.732) total time=   6.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.760) total time=   6.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.776) total time=   8.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.754) total time=   8.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.780) total time=   8.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.734) total time=   8.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.760) total time=   8.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.776) total time=  10.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.753) total time=  10.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.780) total time=   9.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.734) total time=   9.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.758) total time=   9.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.960, test=0.778) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.963, test=0.756) total time=   0.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.963, test=0.770) total time=   0.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.966, test=0.741) total time=   0.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100;, score=(train=0.968, test=0.757) total time=   0.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.773) total time=   1.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.751) total time=   1.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.760) total time=   1.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.713) total time=   1.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500;, score=(train=1.000, test=0.750) total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.770) total time=   1.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.739) total time=   1.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.753) total time=   1.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.702) total time=   1.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000;, score=(train=1.000, test=0.740) total time=   1.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.769) total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.737) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.748) total time=   2.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.698) total time=   2.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500;, score=(train=1.000, test=0.736) total time=   2.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.767) total time=   3.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.736) total time=   3.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.746) total time=   3.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.697) total time=   3.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000;, score=(train=1.000, test=0.735) total time=   3.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.766) total time=   4.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.734) total time=   4.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.745) total time=   4.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.696) total time=   4.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500;, score=(train=1.000, test=0.732) total time=   4.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=1.000, test=0.766) total time=   0.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=1.000, test=0.742) total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=1.000, test=0.760) total time=   0.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=1.000, test=0.731) total time=   0.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100;, score=(train=1.000, test=0.746) total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.765) total time=   1.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.743) total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.749) total time=   1.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.733) total time=   1.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500;, score=(train=1.000, test=0.743) total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.764) total time=   2.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.743) total time=   2.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.750) total time=   2.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.724) total time=   2.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000;, score=(train=1.000, test=0.737) total time=   2.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.764) total time=   3.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.741) total time=   3.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.749) total time=   3.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.721) total time=   3.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500;, score=(train=1.000, test=0.735) total time=   3.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.762) total time=   4.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.739) total time=   4.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.748) total time=   4.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.720) total time=   4.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000;, score=(train=1.000, test=0.733) total time=   4.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.761) total time=   6.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.738) total time=   6.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.747) total time=   5.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.721) total time=   5.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500;, score=(train=1.000, test=0.731) total time=   5.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.764) total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.742) total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.783) total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.716) total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100;, score=(train=1.000, test=0.759) total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.763) total time=   1.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.741) total time=   2.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.776) total time=   1.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.718) total time=   1.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500;, score=(train=1.000, test=0.759) total time=   1.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.762) total time=   3.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.736) total time=   3.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.772) total time=   3.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.715) total time=   3.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000;, score=(train=1.000, test=0.757) total time=   3.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.760) total time=   4.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.732) total time=   4.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.769) total time=   4.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.713) total time=   4.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500;, score=(train=1.000, test=0.753) total time=   4.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.759) total time=   5.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.731) total time=   5.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.768) total time=   5.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.712) total time=   5.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000;, score=(train=1.000, test=0.751) total time=   5.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.759) total time=   6.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.729) total time=   6.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.767) total time=   6.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.711) total time=   6.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500;, score=(train=1.000, test=0.750) total time=   6.0s
# ========================================================================================================================
#
# Runtime: 6:07:59.884908
#
# Average ROC AUC score:      0.7668 [0.76753529 0.77934491 0.76679776 0.75083612 0.7694369 ]
# Average accuracy score:     0.8618 [0.86181139 0.86134454 0.86361513 0.86034563 0.86174685]
# Average precision score:    0.7034 [0.7        0.71428571 0.76923077 0.5        0.83333333]
# Average recall score:       0.0200 [0.02333333 0.01666667 0.03344482 0.01003344 0.01666667]
# Average F1 score:           0.0388 [0.04516129 0.03257329 0.06410256 0.01967213 0.03267974]
#
# Best parameters:
#  {'colsample_bytree': 0.4, 'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}

# %%
joblib.dump(gs, 'multimodal_gridsearch.pkl')
joblib.dump(nested_scores, 'multimodal_nested_scores.pkl')
# Out:
# ['multimodal_nested_scores.pkl']

# %% [markdown]
# # SHAP (SHapley Additive exPlanations)

# %%
explainer = shap.Explainer(gs.best_estimator_)
shap_values = explainer(X)

# %% [markdown]
# # SHAP ranking of top model features

# %%
# Create SHAP ranking dataframe
sv_mean = np.abs(shap_values.values).mean(0)
sv_rank = pd.DataFrame(list(zip(X, sv_mean)), columns=['feature', 'mean absolute SHAP value'])
sv_rank = sv_rank.sort_values(by='mean absolute SHAP value', ascending=False)
sv_rank['percent importance'] = sv_rank['mean absolute SHAP value'] / sv_rank['mean absolute SHAP value'].sum()*100
sv_rank['cumulative importance (%)'] = sv_rank['percent importance'].cumsum()
sv_rank.reset_index(inplace=True, drop=True)
sv_rank.to_csv(f'multimodal_shap_ranking.csv', index=False)

pd.options.display.max_rows = None
print(f"Sum of SHAP values: {sv_rank['mean absolute SHAP value'].sum()}")
sv_rank[:60]
# Out:
# Sum of SHAP values: 3.1259260177612305
#                                     feature  mean absolute SHAP value  \
# 0                               su_risk_p_1                  0.233450
# 1                          site_id_l_site16                  0.151355
# 2                               macv_p_ss_r                  0.139305
# 3                      parent_rules_q1a_3.0                  0.077303
# 4   meim_ethnic_id_p_black/african_american                  0.069535
# 5                               pds_skin2_y                  0.060457
# 6                       parent_rules_q1_1.0                  0.057828
# 7                   pps_y_ss_severity_score                  0.054414
# 8               upps_y_ss_sensation_seeking                  0.052730
# 9                   reshist_addr1_adi_edu_h                  0.051867
# 10                          demo_prnt_ed_v2                  0.050520
# 11                         stq_y_ss_weekend                  0.043143
# 12                                bisbas1_y                  0.040699
# 13                                 upps28_y                  0.038884
# 14                               devhx_18_p                  0.037555
# 15                                 upps12_y                  0.035211
# 16                                 upps27_y                  0.034643
# 17                      pps_y_ss_bother_sum                  0.033487
# 18                      demo_comb_income_v2                  0.030166
# 19                              school_15_y                  0.030061
# 20               upps_y_ss_negative_urgency                  0.029077
# 21                          ravlt_immediate                  0.028897
# 22                 devhx_ss_8_alcohol_max_p                  0.028289
# 23                        asr_scr_somatic_t                  0.027677
# 24                               school_3_y                  0.027437
# 25                              via_p_ss_hc                  0.026446
# 26                           ksads_23_956_t                  0.025785
# 27                          pps_y_ss_number                  0.025470
# 28             devhx_ss_8_alcohol_effects_p                  0.025197
# 29                  reshist_addr1_adi_edu_l                  0.025017
# 30                    reshist_addr1_drgsale                  0.024548
# 31                  parent_rules_q1_allowed                  0.024055
# 32               upps_y_ss_lack_of_planning                  0.023598
# 33                           ksads_23_957_t                  0.022890
# 34                   reshist_addr1_adi_b138                  0.022755
# 35           reshist_addr1_leadrisk_housing                  0.019963
# 36                          sleepdisturb1_p                  0.019905
# 37                          crpbi_parent3_y                  0.019897
# 38                 reshist_addr1_adi_income                  0.019482
# 39                             macv_p_ss_fo                  0.018597
# 40                  reshist_addr1_elevation                  0.017955
# 41                          bis_y_ss_bas_fs                  0.017781
# 42                  reshist_addr1_adi_crowd                  0.017631
# 43                               school_8_y                  0.017556
# 44                            macv_p_ss_isr                  0.017454
# 45                                 upps20_y                  0.017440
# 46                         anthroheightcalc                  0.016987
# 47                 devhx_ss_8_alcohol_avg_p                  0.016909
# 48                  reshist_addr1_adi_unemp                  0.014199
# 49                 reshist_addr1_pm252016aa                  0.014138
# 50                           ksads_23_958_t                  0.014019
# 51                      parent_rules_q8_3.0                  0.013283
# 52                 reshist_addr1_adi_home_v                  0.013205
# 53                            sds_p_ss_does                  0.013127
# 54                           kbi_y_trans_id                  0.012794
# 55                               school_4_y                  0.012715
# 56                            via_p_ss_amer                  0.012515
# 57                  reshist_addr1_walkindex                  0.012477
# 58                               school_9_y                  0.012420
# 59                        reshist_addr1_d1a                  0.012326
#
#     percent importance  cumulative importance (%)
# 0             7.468202                   7.468202
# 1             4.841926                  12.310128
# 2             4.456448                  16.766577
# 3             2.472975                  19.239552
# 4             2.224456                  21.464008
# 5             1.934036                  23.398045
# 6             1.849941                  25.247986
# 7             1.740738                  26.988724
# 8             1.686845                  28.675570
# 9             1.659246                  30.334816
# 10            1.616162                  31.950977
# 11            1.380182                  33.331158
# 12            1.301987                  34.633144
# 13            1.243935                  35.877079
# 14            1.201415                  37.078495
# 15            1.126429                  38.204926
# 16            1.108250                  39.313175
# 17            1.071276                  40.384453
# 18            0.965041                  41.349495
# 19            0.961669                  42.311165
# 20            0.930179                  43.241344
# 21            0.924422                  44.165768
# 22            0.904984                  45.070751
# 23            0.885418                  45.956169
# 24            0.877737                  46.833904
# 25            0.846030                  47.679935
# 26            0.824878                  48.504814
# 27            0.814783                  49.319595
# 28            0.806061                  50.125656
# 29            0.800308                  50.925964
# 30            0.785303                  51.711266
# 31            0.769531                  52.480797
# 32            0.754911                  53.235706
# 33            0.732270                  53.967976
# 34            0.727933                  54.695908
# 35            0.638634                  55.334541
# 36            0.636762                  55.971302
# 37            0.636503                  56.607803
# 38            0.623239                  57.231041
# 39            0.594934                  57.825974
# 40            0.574395                  58.400368
# 41            0.568831                  58.969200
# 42            0.564034                  59.533234
# 43            0.561617                  60.094849
# 44            0.558371                  60.653221
# 45            0.557904                  61.211124
# 46            0.543419                  61.754543
# 47            0.540917                  62.295460
# 48            0.454248                  62.749706
# 49            0.452266                  63.201973
# 50            0.448485                  63.650459
# 51            0.424923                  64.075386
# 52            0.422436                  64.497826
# 53            0.419937                  64.917763
# 54            0.409281                  65.327042
# 55            0.406747                  65.733788
# 56            0.400364                  66.134148
# 57            0.399147                  66.533295
# 58            0.397308                  66.930603
# 59            0.394312                  67.324913

# %% [markdown]
# # SHAP summary plot of top features

# %%
shap.plots.beeswarm(shap_values, max_display=61)

# %% [markdown]
# # SHAP dependence plots

# %%
top_inds = np.argsort(-np.sum(np.abs(shap_values.values), 0))
for i in range(60):
    shap.plots.scatter(shap_values[:, top_inds[i]], color=shap_values)
