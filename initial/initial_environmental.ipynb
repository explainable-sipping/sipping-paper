# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # read data function

# %%
def read_abcd(path, cols, na_values):
    
    df = pd.read_csv(path, sep='\t', index_col='subjectkey', na_values=na_values)
    df = df.drop(df.index[0])
    
    for col in cols:
        df[col] = pd.to_numeric(df[col])
        df = df[cols]

    df = df.reset_index()
    df = df.sort_values(['subjectkey', 'interview_age'])
    df = df.drop_duplicates(subset=['subjectkey'], keep='first')
    df = df.drop(columns=['interview_age'])
    df = df.set_index('subjectkey')
    
    df_show = abcd_ysu02.join(df)
    df_show = df_show.drop(columns=[
        'isip_1d_2',
        'isip_5_2',
        'isip_1b_yn'
    ])
     
    for col in df_show.columns:
        print('{:<30}    n = {:<10}    mean = {:<10.4f}'.\
              format(col,  df_show[col].notnull().sum(), df_show[col].mean()))    
    print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
    
    return df

# %% [markdown]
# # y target variable

# %%
file_abcd_ysu02 = r'E:\gregn\data\ABCD\abcd3\abcd_ysu02.txt'
abcd_ysu02 = pd.read_csv(file_abcd_ysu02, sep='\t', index_col='subjectkey')
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02.index[0])
cols = [
    'interview_age',
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
]

for col in cols:
    abcd_ysu02[col] = pd.to_numeric(abcd_ysu02[col])
    abcd_ysu02 = abcd_ysu02[cols]
    
abcd_ysu02 = abcd_ysu02.reset_index()
abcd_ysu02 = abcd_ysu02.sort_values(['subjectkey', 'interview_age'])
abcd_ysu02 = abcd_ysu02.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_ysu02 = abcd_ysu02.drop(columns=['interview_age'])
abcd_ysu02 = abcd_ysu02.set_index('subjectkey')
    
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_5_2 == 3].index) # drop accidental 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_5_2 == 2].index) # drop sneaky 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_1b_yn == 0].index) # drop religious 
abcd_ysu02 = abcd_ysu02.drop(abcd_ysu02[abcd_ysu02.isip_1d_2 > 10].index)

abcd_ysu02['isip_1d_2'] = abcd_ysu02['isip_1d_2'].fillna(0)

y = abcd_ysu02['isip_1d_2'].values
y = np.where(y>0, 1, y)

unique, counts = np.unique(y, return_counts=True)

print('number of subjects: {:>10}\n\n[0] never sipped: {:>12}\n[1] sipped by age 10:{:>9}'.\
      format(len(y), counts[0], counts[1]))
# Out:
# number of subjects:      10707
#
# [0] never sipped:         9209
# [1] sipped by age 10:     1498

# %% [markdown]
# # abcd_asrs01

# %%
path = r'E:\gregn\data\ABCD\abcd3\abcd_asrs01.txt'

cols = [
    'interview_age',
    'asr_scr_perstr_t',
    'asr_scr_anxdep_t',
    'asr_scr_withdrawn_t',
    'asr_scr_somatic_t',
    'asr_scr_thought_t',
    'asr_scr_attention_t',
    'asr_scr_aggressive_t',
    'asr_scr_rulebreak_t',
    'asr_scr_intrusive_t',
    'asr_scr_internal_t',
    'asr_scr_external_t',
    'asr_scr_totprob_t',
    'asr_scr_depress_t',
    'asr_scr_anxdisord_t',
    'asr_scr_somaticpr_t',
    'asr_scr_avoidant_t',
    'asr_scr_adhd_t',
    'asr_scr_antisocial_t',
    'asr_scr_inattention_t',
    'asr_scr_hyperactive_t'    
]

na_values = [None]
abcd_asrs01 = read_abcd(path, cols, na_values)
# Out:
# asr_scr_perstr_t                  n = 10608         mean = 47.8090
# asr_scr_anxdep_t                  n = 10608         mean = 53.4521
# asr_scr_withdrawn_t               n = 10608         mean = 52.8366
# asr_scr_somatic_t                 n = 10608         mean = 54.7870
# asr_scr_thought_t                 n = 10608         mean = 52.9399
# asr_scr_attention_t               n = 10608         mean = 53.9073
# asr_scr_aggressive_t              n = 10608         mean = 53.3350
# asr_scr_rulebreak_t               n = 10608         mean = 52.5679
# asr_scr_intrusive_t               n = 10608         mean = 51.6443
# asr_scr_internal_t                n = 10608         mean = 48.1090
# asr_scr_external_t                n = 10608         mean = 45.9104
# asr_scr_totprob_t                 n = 10608         mean = 42.9776
# asr_scr_depress_t                 n = 10608         mean = 54.0254
# asr_scr_anxdisord_t               n = 10608         mean = 53.5172
# asr_scr_somaticpr_t               n = 10608         mean = 54.8087
# asr_scr_avoidant_t                n = 10608         mean = 53.2191
# asr_scr_adhd_t                    n = 10608         mean = 53.2591
# asr_scr_antisocial_t              n = 10608         mean = 53.0080
# asr_scr_inattention_t             n = 10608         mean = 54.3189
# asr_scr_hyperactive_t             n = 10608         mean = 52.0309
#
# subjects:     10707
# features:        20

# %% [markdown]
# # abcd_rhds01

# %%
path = r'E:\gregn\data\ABCD\abcd3\abcd_rhds01.txt'

cols = [
    'interview_age',
    'reshist_addr1_years',
    'reshist_addr1_elevation',
    'reshist_addr1_d1a',
    'reshist_addr1_walkindex',
    'reshist_addr1_grndtot',
    'reshist_addr1_p1tot',
    'reshist_addr1_p1vlnt',
    'reshist_addr1_drugtot',
    'reshist_addr1_drgsale',
    'reshist_addr1_mjsale',
    'reshist_addr1_drgposs',
    'reshist_addr1_dui',
    'reshist_addr1_adi_edu_l',
    'reshist_addr1_adi_edu_h',
    'reshist_addr1_adi_work_c',
    'reshist_addr1_adi_income',
    'reshist_addr1_adi_in_dis',
    'reshist_addr1_adi_home_v',
    'reshist_addr1_adi_rent',
    'reshist_addr1_adi_mortg',
    'reshist_addr1_adi_home_o',
    'reshist_addr1_adi_crowd',
    'reshist_addr1_adi_unemp',
    'reshist_addr1_adi_pov',
    'reshist_addr1_adi_b138',
    'reshist_addr1_adi_sp',
    'reshist_addr1_adi_ncar',
    'reshist_addr1_adi_ntel',
    'reshist_addr1_adi_nplumb',
    'reshist_addr1_adi_wsum',
    'reshist_addr1_adi_perc',
    'reshist_addr1_popdensity',
    'reshist_addr1_no2',
    'reshist_addr1_pm25',
    'reshist_addr1_proxrd',
    'reshist_addr1_pm252016aa',
    'reshist_addr1_leadrisk_poverty',
    'reshist_addr1_leadrisk_housing',
    'reshist_addr1_leadrisk'
]

na_values = [None]
abcd_rhds01 = read_abcd(path, cols, na_values)
# Out:
# reshist_addr1_years               n = 9792          mean = 5.4184
# reshist_addr1_elevation           n = 8233          mean = 332.7681
# reshist_addr1_d1a                 n = 10072         mean = 3.9956
# reshist_addr1_walkindex           n = 10072         mean = 10.6656
# reshist_addr1_grndtot             n = 10072         mean = 52293.7664
# reshist_addr1_p1tot               n = 10072         mean = 10235.8680
# reshist_addr1_p1vlnt              n = 10072         mean = 3564.0520
# reshist_addr1_drugtot             n = 10072         mean = 7264.1187
# reshist_addr1_drgsale             n = 10072         mean = 1311.3219
# reshist_addr1_mjsale              n = 10072         mean = 462.0419
# reshist_addr1_drgposs             n = 10072         mean = 5928.4164
# reshist_addr1_dui                 n = 10072         mean = 5742.8614
# reshist_addr1_adi_edu_l           n = 10072         mean = 5.0213
# reshist_addr1_adi_edu_h           n = 10072         mean = 88.0090
# reshist_addr1_adi_work_c          n = 10072         mean = 93.6760
# reshist_addr1_adi_income          n = 10072         mean = 75804.2945
# reshist_addr1_adi_in_dis          n = 10072         mean = 2.1559
# reshist_addr1_adi_home_v          n = 10072         mean = 256802.6945
# reshist_addr1_adi_rent            n = 10072         mean = 1089.4892
# reshist_addr1_adi_mortg           n = 10072         mean = 1429.7834
# reshist_addr1_adi_home_o          n = 10072         mean = 65.0945
# reshist_addr1_adi_crowd           n = 10072         mean = 3.7534
# reshist_addr1_adi_unemp           n = 10072         mean = 9.1604
# reshist_addr1_adi_pov             n = 10072         mean = 11.7646
# reshist_addr1_adi_b138            n = 10072         mean = 21.5500
# reshist_addr1_adi_sp              n = 10072         mean = 18.2757
# reshist_addr1_adi_ncar            n = 10072         mean = 9.1086
# reshist_addr1_adi_ntel            n = 10072         mean = 2.1832
# reshist_addr1_adi_nplumb          n = 10072         mean = 0.3131
# reshist_addr1_adi_wsum            n = 10072         mean = 93.1523
# reshist_addr1_adi_perc            n = 10072         mean = 39.6715
# reshist_addr1_popdensity          n = 10072         mean = 2213.3606
# reshist_addr1_no2                 n = 10072         mean = 2.4505
# reshist_addr1_pm25                n = 10072         mean = 7.5162
# reshist_addr1_proxrd              n = 10072         mean = 1180.3478
# reshist_addr1_pm252016aa          n = 10070         mean = 7.6775
# reshist_addr1_leadrisk_poverty    n = 10070         mean = 19.1337
# reshist_addr1_leadrisk_housing    n = 10070         mean = 20.7671
# reshist_addr1_leadrisk            n = 10070         mean = 5.0967
#
# subjects:     10707
# features:        39

# %% [markdown]
# # abcd_fes01

# %%
path = r'E:\gregn\data\ABCD\abcd3\abcd_fes01.txt'

cols = [
    'interview_age',
    'fes_youth_q1',
    'fes_youth_q2',
    'fes_youth_q3',
    'fes_youth_q4',
    'fes_youth_q5',
    'fes_youth_q6',
    'fes_youth_q7',
    'fes_youth_q8',
    'fes_youth_q9',
]

na_values = [None]
abcd_fes01 = read_abcd(path, cols, na_values)
# Out:
# fes_youth_q1                      n = 10682         mean = 0.2406
# fes_youth_q2                      n = 10683         mean = 0.3312
# fes_youth_q3                      n = 10684         mean = 0.1227
# fes_youth_q4                      n = 10684         mean = 0.3616
# fes_youth_q5                      n = 10684         mean = 0.1912
# fes_youth_q6                      n = 10683         mean = 0.2197
# fes_youth_q7                      n = 10684         mean = 0.0935
# fes_youth_q8                      n = 10684         mean = 0.2259
# fes_youth_q9                      n = 10684         mean = 0.2410
#
# subjects:     10707
# features:         9

# %% [markdown]
# # fes02

# %%
path = r'E:\gregn\data\ABCD\abcd3\fes02.txt'

cols = [
    'interview_age',
    'fam_enviro1_p',
    'fam_enviro2r_p',
    'fam_enviro3_p',
    'fam_enviro4r_p',
    'fam_enviro5_p',
    'fam_enviro6_p',
    'fam_enviro7r_p',
    'fam_enviro8_p',
    'fam_enviro9r_p'
]

na_values = [None]
fes02 = read_abcd(path, cols, na_values)
# Out:
# fam_enviro1_p                     n = 10703         mean = 0.1628
# fam_enviro2r_p                    n = 10702         mean = 0.5010
# fam_enviro3_p                     n = 10703         mean = 0.1276
# fam_enviro4r_p                    n = 10703         mean = 0.5154
# fam_enviro5_p                     n = 10703         mean = 0.3265
# fam_enviro6_p                     n = 10703         mean = 0.1240
# fam_enviro7r_p                    n = 10703         mean = 0.1096
# fam_enviro8_p                     n = 10703         mean = 0.1754
# fam_enviro9r_p                    n = 10697         mean = 0.4840
#
# subjects:     10707
# features:         9

# %% [markdown]
# # abcd_ptsd01

# %%
path = r'E:\gregn\data\ABCD\abcd3\abcd_ptsd01.txt'

cols = [
    'interview_age',
    'ksads_ptsd_raw_754_p',
    'ksads_ptsd_raw_755_p',
    'ksads_ptsd_raw_756_p',
    'ksads_ptsd_raw_757_p',
    'ksads_ptsd_raw_758_p',
    'ksads_ptsd_raw_759_p',
    'ksads_ptsd_raw_760_p', 
    'ksads_ptsd_raw_761_p',
    'ksads_ptsd_raw_762_p', # family
    'ksads_ptsd_raw_763_p', # family
    'ksads_ptsd_raw_764_p',
    'ksads_ptsd_raw_765_p', # family 
    'ksads_ptsd_raw_766_p', # family 
    'ksads_ptsd_raw_767_p', # family 
    'ksads_ptsd_raw_768_p',
    'ksads_ptsd_raw_769_p',
    'ksads_ptsd_raw_770_p'
]

na_values = [None]
abcd_ptsd01 = read_abcd(path, cols, na_values)
# Out:
# ksads_ptsd_raw_754_p              n = 10417         mean = 0.0386
# ksads_ptsd_raw_755_p              n = 10417         mean = 0.0418
# ksads_ptsd_raw_756_p              n = 10417         mean = 0.0219
# ksads_ptsd_raw_757_p              n = 10417         mean = 0.0259
# ksads_ptsd_raw_758_p              n = 10417         mean = 0.0033
# ksads_ptsd_raw_759_p              n = 10417         mean = 0.0047
# ksads_ptsd_raw_760_p              n = 10417         mean = 0.0103
# ksads_ptsd_raw_761_p              n = 10417         mean = 0.0037
# ksads_ptsd_raw_762_p              n = 10417         mean = 0.0037
# ksads_ptsd_raw_763_p              n = 10417         mean = 0.0089
# ksads_ptsd_raw_764_p              n = 10417         mean = 0.0069
# ksads_ptsd_raw_765_p              n = 10417         mean = 0.0060
# ksads_ptsd_raw_766_p              n = 10417         mean = 0.0798
# ksads_ptsd_raw_767_p              n = 10417         mean = 0.0049
# ksads_ptsd_raw_768_p              n = 10417         mean = 0.0070
# ksads_ptsd_raw_769_p              n = 10417         mean = 0.0132
# ksads_ptsd_raw_770_p              n = 10417         mean = 0.2412
#
# subjects:     10707
# features:        17

# %%
abcd_ptsd01['ksads_ptsd_home'] = (abcd_ptsd01.ksads_ptsd_raw_762_p
                                 + abcd_ptsd01.ksads_ptsd_raw_763_p
                                 + abcd_ptsd01.ksads_ptsd_raw_765_p
                                 + abcd_ptsd01.ksads_ptsd_raw_766_p
                                 + abcd_ptsd01.ksads_ptsd_raw_767_p)

abcd_ptsd01['ksads_ptsd_outside_home'] = (abcd_ptsd01.ksads_ptsd_raw_754_p
                                         + abcd_ptsd01.ksads_ptsd_raw_755_p
                                         + abcd_ptsd01.ksads_ptsd_raw_756_p
                                         + abcd_ptsd01.ksads_ptsd_raw_757_p
                                         + abcd_ptsd01.ksads_ptsd_raw_758_p
                                         + abcd_ptsd01.ksads_ptsd_raw_759_p
                                         + abcd_ptsd01.ksads_ptsd_raw_760_p
                                         + abcd_ptsd01.ksads_ptsd_raw_761_p
                                         + abcd_ptsd01.ksads_ptsd_raw_764_p
                                         + abcd_ptsd01.ksads_ptsd_raw_768_p
                                         + abcd_ptsd01.ksads_ptsd_raw_769_p
                                         + abcd_ptsd01.ksads_ptsd_raw_770_p)

abcd_ptsd01 = abcd_ptsd01[['ksads_ptsd_home', 'ksads_ptsd_outside_home']]

# %% [markdown]
# # abcd_crpf01

# %%
path = r'E:\gregn\data\ABCD\abcd3\abcd_crpf01.txt'

cols = [
    'interview_age',
    'su_risk_p_1',
    'su_risk_p_2',
    'su_risk_p_3',
    'su_risk_p_4',
    'su_risk_p_5',
    'su_risk_p_6',
    'su_risk_p_7',
    'su_risk_p_8',
    'su_risk_p_9',
]

na_values = ['777', '999']
abcd_crpf01 = read_abcd(path, cols, na_values)
# Out:
# su_risk_p_1                       n = 10699         mean = 1.0855
# su_risk_p_2                       n = 10699         mean = 0.4566
# su_risk_p_3                       n = 10699         mean = 0.3834
# su_risk_p_4                       n = 10699         mean = 0.3764
# su_risk_p_5                       n = 10699         mean = 0.2999
# su_risk_p_6                       n = 10699         mean = 0.8159
# su_risk_p_7                       n = 4657          mean = 0.8338
# su_risk_p_8                       n = 4662          mean = 0.8539
# su_risk_p_9                       n = 4079          mean = 2.0625
#
# subjects:     10707
# features:         9

# %% [markdown]
# # pmq01

# %%
path = r'E:\gregn\data\ABCD\abcd3\pmq01.txt'

cols = [
    'interview_age',
    'parent_monitor_q1_y',
    'parent_monitor_q2_y',
    'parent_monitor_q3_y',
    'parent_monitor_q4_y',
    'parent_monitor_q5_y'
]

na_values = [None]
pmq01 = read_abcd(path, cols, na_values)
# Out:
# parent_monitor_q1_y               n = 10687         mean = 4.7216
# parent_monitor_q2_y               n = 10685         mean = 4.5896
# parent_monitor_q3_y               n = 10686         mean = 4.5455
# parent_monitor_q4_y               n = 10687         mean = 3.7554
# parent_monitor_q5_y               n = 10687         mean = 4.3173
#
# subjects:     10707
# features:         5

# %% [markdown]
# # crpbi01

# %%
path = r'E:\gregn\data\ABCD\abcd3\crpbi01.txt'

cols = [
    'interview_age',
    'crpbi_parent1_y',
    'crpbi_parent2_y',
    'crpbi_parent3_y',
    'crpbi_parent4_y',
    'crpbi_parent5_y',
    'crpbi_caregiver1_y',
]

na_values = [None]
crpbi01 = read_abcd(path, cols, na_values)
# Out:
# crpbi_parent1_y                   n = 10676         mean = 2.7740
# crpbi_parent2_y                   n = 10675         mean = 2.7402
# crpbi_parent3_y                   n = 10674         mean = 2.7924
# crpbi_parent4_y                   n = 10674         mean = 2.9347
# crpbi_parent5_y                   n = 10672         mean = 2.6782
# crpbi_caregiver1_y                n = 10667         mean = 0.9255
#
# subjects:     10707
# features:         6

# %% [markdown]
# # pdem02

# %%
file_pdem02 = r'E:\gregn\data\ABCD\abcd3\pdem02.txt'
pdem02 = pd.read_csv(file_pdem02, sep='\t', index_col='subjectkey', na_values=['777', '999'])
pdem02 = pdem02.drop(pdem02.index[0])

cols = [
    'interview_age',
    'demo_prim',
    'demo_adopt_agex_v2',
    'demo_sex_v2',
    'demo_gender_id_v2',
    'demo_prnt_age_v2',
    'demo_prnt_gender_id_v2',
    'demo_prnt_marital_v2',
    'demo_prnt_ed_v2',
    'demo_prnt_empl_v2',
    'demo_prnt_empl_time',
    'demo_prnt_income_v2',
    'demo_prnt_prtnr_v2',
    'demo_comb_income_v2',
    'demo_fam_exp1_v2',
    'demo_fam_exp2_v2',
    'demo_fam_exp3_v2',
    'demo_fam_exp4_v2',
    'demo_fam_exp5_v2',
    'demo_fam_exp6_v2',
    'demo_fam_exp7_v2'
]

for col in cols:
    pdem02[col] = pd.to_numeric(pdem02[col])
    pdem02 = pdem02[cols]
    
pdem02 = pd.get_dummies(pdem02, columns=[
    'demo_prim',
    'demo_sex_v2',
    'demo_gender_id_v2',
    'demo_prnt_gender_id_v2',
    'demo_prnt_marital_v2',
    'demo_prnt_empl_v2',
])

pdem02 = pdem02.rename(columns={
    'demo_prim_1': 'demo_prim_biological_mother',
    'demo_prim_2': 'demo_prim_biological_father',
    'demo_prim_3': 'demo_prim_adoptive_parent',
    'demo_prim_4': 'demo_prim_custodial_parent',
    'demo_prim_5': 'demo_prim_other',
    'demo_sex_v2_1': 'demo_sex_v2_male',
    'demo_sex_v2_2': 'demo_sex_v2_female',
    'demo_sex_v2_3': 'demo_sex_v2_intersex-male', 
    'demo_gender_id_v2_1.0': 'demo_gender_id_v2_male',
    'demo_gender_id_v2_2.0': 'demo_gender_id_v2_female',
    'demo_gender_id_v2_3.0': 'demo_gender_id_v2_trans_male',
    'demo_gender_id_v2_4.0': 'demo_gender_id_v2_trans_female',
    'demo_gender_id_v2_5.0': 'demo_gender_id_v2_gender_queer',
    'demo_gender_id_v2_6.0': 'demo_gender_id_v2_different',
    'demo_prnt_gender_id_v2_1.0': 'demo_prnt_gender_id_v2_male',
    'demo_prnt_gender_id_v2_2.0': 'demo_prnt_gender_id_v2_female',
    'demo_prnt_gender_id_v2_3.0': 'demo_prnt_gender_id_v2_trans_male',
    'demo_prnt_gender_id_v2_4.0': 'demo_prnt_gender_id_v2_trans_female',
    'demo_prnt_gender_id_v2_5.0': 'demo_prnt_gender_id_v2_gender_queer',
    'demo_prnt_gender_id_v2_6.0': 'demo_prnt_gender_id_v2_different',
    'demo_prnt_marital_v2_1.0': 'demo_prnt_marital_v2_married',
    'demo_prnt_marital_v2_2.0': 'demo_prnt_marital_v2_widowed',
    'demo_prnt_marital_v2_3.0': 'demo_prnt_marital_v2_divorced',
    'demo_prnt_marital_v2_4.0': 'demo_prnt_marital_v2_separated',
    'demo_prnt_marital_v2_5.0': 'demo_prnt_marital_v2_never_married',
    'demo_prnt_marital_v2_6.0': 'demo_prnt_marital_v2_living_with_partner',
    'demo_prnt_empl_v2_1.0': 'demo_prnt_empl_v2_working_now',
    'demo_prnt_empl_v2_2.0': 'demo_prnt_empl_v2_temporarily_laid_off',
    'demo_prnt_empl_v2_3.0': 'demo_prnt_empl_v2_looking_for_work',
    'demo_prnt_empl_v2_4.0': 'demo_prnt_empl_v2_retired',
    'demo_prnt_empl_v2_5.0': 'demo_prnt_empl_v2_disabled',
    'demo_prnt_empl_v2_6.0': 'demo_prnt_empl_v2_stay_at_home_parent',
    'demo_prnt_empl_v2_7.0': 'demo_prnt_empl_v2_student',
    'demo_prnt_empl_v2_8.0': 'demo_prnt_empl_v2_other',
    'demo_prnt_empl_v2_9.0': 'demo_prnt_empl_v2_sick_leave',
    'demo_prnt_empl_v2_10.0': 'demo_prnt_empl_v2_maternity_leave',
    'demo_prnt_empl_v2_11.0': 'demo_prnt_empl_v2_unemployed_not_looking'   
})


pdem02['demo_gender_id_v2_non-binary'] = (pdem02.demo_gender_id_v2_trans_male
                                         + pdem02.demo_gender_id_v2_trans_female
                                         + pdem02.demo_gender_id_v2_gender_queer
                                         + pdem02.demo_gender_id_v2_different)

pdem02['demo_prnt_gender_id_v2_non-binary'] = (pdem02.demo_prnt_gender_id_v2_trans_male
                                              + pdem02.demo_prnt_gender_id_v2_trans_female
                                              + pdem02.demo_prnt_gender_id_v2_gender_queer
                                              + pdem02.demo_prnt_gender_id_v2_different)


pdem02 = pdem02.drop(columns=[
    'demo_gender_id_v2_trans_male',
    'demo_gender_id_v2_trans_female',
    'demo_gender_id_v2_gender_queer',
    'demo_gender_id_v2_different',
    'demo_prnt_gender_id_v2_trans_male',
    'demo_prnt_gender_id_v2_trans_female',
    'demo_prnt_gender_id_v2_gender_queer',
    'demo_prnt_gender_id_v2_different',
    'demo_sex_v2_intersex-male'
])

pdem02 = pdem02.reset_index()
pdem02 = pdem02.sort_values(['subjectkey', 'interview_age'])
pdem02 = pdem02.drop_duplicates(subset=['subjectkey'], keep='first')
pdem02 = pdem02.drop(columns=['interview_age'])
pdem02 = pdem02.set_index('subjectkey')

df_show = abcd_ysu02.join(pdem02)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<40}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# demo_adopt_agex_v2                          n = 252           mean = 2.2289        sum = 561.68
# demo_prnt_age_v2                            n = 10620         mean = 39.8566       sum = 423277.1
# demo_prnt_ed_v2                             n = 10692         mean = 16.5397       sum = 176843.0
# demo_prnt_empl_time                         n = 7314          mean = 1.2740        sum = 9318.0
# demo_prnt_income_v2                         n = 9699          mean = 4.8610        sum = 47147.0
# demo_prnt_prtnr_v2                          n = 10594         mean = 1.1937        sum = 12646.0
# demo_comb_income_v2                         n = 9772          mean = 7.1823        sum = 70185.0
# demo_fam_exp1_v2                            n = 10632         mean = 0.0837        sum = 890.0
# demo_fam_exp2_v2                            n = 10661         mean = 0.0623        sum = 664.0
# demo_fam_exp3_v2                            n = 10649         mean = 0.1097        sum = 1168.0
# demo_fam_exp4_v2                            n = 10676         mean = 0.0148        sum = 158.0
# demo_fam_exp5_v2                            n = 10664         mean = 0.0571        sum = 609.0
# demo_fam_exp6_v2                            n = 10668         mean = 0.0529        sum = 564.0
# demo_fam_exp7_v2                            n = 10661         mean = 0.1040        sum = 1109.0
# demo_prim_biological_mother                 n = 10707         mean = 0.8522        sum = 9125
# demo_prim_biological_father                 n = 10707         mean = 0.1000        sum = 1071
# demo_prim_adoptive_parent                   n = 10707         mean = 0.0239        sum = 256
# demo_prim_custodial_parent                  n = 10707         mean = 0.0104        sum = 111
# demo_prim_other                             n = 10707         mean = 0.0134        sum = 144
# demo_sex_v2_male                            n = 10707         mean = 0.5189        sum = 5556
# demo_sex_v2_female                          n = 10707         mean = 0.4807        sum = 5147
# demo_gender_id_v2_male                      n = 10707         mean = 0.5183        sum = 5549
# demo_gender_id_v2_female                    n = 10707         mean = 0.4797        sum = 5136
# demo_prnt_gender_id_v2_male                 n = 10707         mean = 0.1088        sum = 1165
# demo_prnt_gender_id_v2_female               n = 10707         mean = 0.8887        sum = 9515
# demo_prnt_marital_v2_married                n = 10707         mean = 0.6717        sum = 7192
# demo_prnt_marital_v2_widowed                n = 10707         mean = 0.0083        sum = 89
# demo_prnt_marital_v2_divorced               n = 10707         mean = 0.0899        sum = 963
# demo_prnt_marital_v2_separated              n = 10707         mean = 0.0390        sum = 418
# demo_prnt_marital_v2_never_married          n = 10707         mean = 0.1246        sum = 1334
# demo_prnt_marital_v2_living_with_partner    n = 10707         mean = 0.0580        sum = 621
# demo_prnt_empl_v2_working_now               n = 10707         mean = 0.6856        sum = 7341
# demo_prnt_empl_v2_temporarily_laid_off      n = 10707         mean = 0.0080        sum = 86
# demo_prnt_empl_v2_looking_for_work          n = 10707         mean = 0.0424        sum = 454
# demo_prnt_empl_v2_retired                   n = 10707         mean = 0.0062        sum = 66
# demo_prnt_empl_v2_disabled                  n = 10707         mean = 0.0228        sum = 244
# demo_prnt_empl_v2_stay_at_home_parent       n = 10707         mean = 0.1783        sum = 1909
# demo_prnt_empl_v2_student                   n = 10707         mean = 0.0209        sum = 224
# demo_prnt_empl_v2_other                     n = 10707         mean = 0.0191        sum = 205
# demo_prnt_empl_v2_sick_leave                n = 10707         mean = 0.0017        sum = 18
# demo_prnt_empl_v2_maternity_leave           n = 10707         mean = 0.0025        sum = 27
# demo_prnt_empl_v2_unemployed_not_looking    n = 10707         mean = 0.0076        sum = 81
# demo_gender_id_v2_non-binary                n = 10707         mean = 0.0011        sum = 12
# demo_prnt_gender_id_v2_non-binary           n = 10707         mean = 0.0020        sum = 21
#
# subjects:     10707
# features:        44

# %% [markdown]
# # abcd_meim01

# %%
file_abcd_meim01 = r'E:\gregn\data\ABCD\abcd3\abcd_meim01.txt'
abcd_meim01 = pd.read_csv(file_abcd_meim01, sep='\t', index_col='subjectkey', na_values=['777', '999'])
abcd_meim01 = abcd_meim01.drop(abcd_meim01.index[0])

cols = [
    'interview_age',
    'meim_ethnic_id_p',
]

for col in cols:
    abcd_meim01[col] = pd.to_numeric(abcd_meim01[col])
    abcd_meim01 = abcd_meim01[cols]

abcd_meim01 = pd.get_dummies(abcd_meim01, columns=['meim_ethnic_id_p'])

abcd_meim01 = abcd_meim01.rename(columns={
    'meim_ethnic_id_p_0.0': 'meim_ethnic_id_p_none',
    'meim_ethnic_id_p_1.0': 'meim_ethnic_id_p_white/caucasian',
    'meim_ethnic_id_p_2.0': 'meim_ethnic_id_p_western_european',
    'meim_ethnic_id_p_3.0': 'meim_ethnic_id_p_eastern_european',
    'meim_ethnic_id_p_4.0': 'meim_ethnic_id_p_hispanic/latino',
    'meim_ethnic_id_p_5.0': 'meim_ethnic_id_p_black/african_american',
    'meim_ethnic_id_p_6.0': 'meim_ethnic_id_p_afro-carribean/indo-carribbean/west_indian',
    'meim_ethnic_id_p_7.0': 'meim_ethnic_id_p_east_asian',
    'meim_ethnic_id_p_8.0': 'meim_ethnic_id_p_south_asian',
    'meim_ethnic_id_p_9.0': 'meim_ethnic_id_p_southeast_asian',
    'meim_ethnic_id_p_10.0': 'meim_ethnic_id_p_american_indian/alaska_native',
    'meim_ethnic_id_p_11.0': 'meim_ethnic_id_p_middle_eastern/north_african',
    'meim_ethnic_id_p_12.0': 'meim_ethnic_id_p_native_hawaiian_or_pacific_islander',
    'meim_ethnic_id_p_13.0': 'meim_ethnic_id_p_mixed',
    'meim_ethnic_id_p_14.0': 'meim_ethnic_id_p_other'
})

abcd_meim01 = abcd_meim01.reset_index()
abcd_meim01 = abcd_meim01.sort_values(['subjectkey', 'interview_age'])
abcd_meim01 = abcd_meim01.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_meim01 = abcd_meim01.drop(columns=['interview_age'])
abcd_meim01 = abcd_meim01.set_index('subjectkey')

df_show = abcd_ysu02.join(abcd_meim01)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<60}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# meim_ethnic_id_p_none                                           n = 10707         mean = 0.0663        sum = 710
# meim_ethnic_id_p_white/caucasian                                n = 10707         mean = 0.5314        sum = 5690
# meim_ethnic_id_p_western_european                               n = 10707         mean = 0.0128        sum = 137
# meim_ethnic_id_p_eastern_european                               n = 10707         mean = 0.0040        sum = 43
# meim_ethnic_id_p_hispanic/latino                                n = 10707         mean = 0.1455        sum = 1558
# meim_ethnic_id_p_black/african_american                         n = 10707         mean = 0.1454        sum = 1557
# meim_ethnic_id_p_afro-carribean/indo-carribbean/west_indian     n = 10707         mean = 0.0028        sum = 30
# meim_ethnic_id_p_east_asian                                     n = 10707         mean = 0.0182        sum = 195
# meim_ethnic_id_p_south_asian                                    n = 10707         mean = 0.0048        sum = 51
# meim_ethnic_id_p_southeast_asian                                n = 10707         mean = 0.0099        sum = 106
# meim_ethnic_id_p_american_indian/alaska_native                  n = 10707         mean = 0.0069        sum = 74
# meim_ethnic_id_p_middle_eastern/north_african                   n = 10707         mean = 0.0029        sum = 31
# meim_ethnic_id_p_native_hawaiian_or_pacific_islander            n = 10707         mean = 0.0021        sum = 22
# meim_ethnic_id_p_mixed                                          n = 10707         mean = 0.0255        sum = 273
# meim_ethnic_id_p_other                                          n = 10707         mean = 0.0029        sum = 31
#
# subjects:     10707
# features:        15

# %% [markdown]
# # abcd_sscep01

# %%
path = r'E:\gregn\data\ABCD\abcd3\abcd_sscep01.txt'

cols = [
    'interview_age',
    'meim_p_ss_exp',
    'meim_p_ss_com',
    'meim_p_ss_total',
    'via_p_ss_hc',
    'via_p_ss_amer',
    'nsc_p_ss_mean_3_items',
    'fes_p_ss_fc_pr',
    'macv_p_ss_fs',
    'macv_p_ss_fo',
    'macv_p_ss_isr',
    'macv_p_ss_fr',
    'macv_p_ss_r',
    'psb_p_ss_mean',
    
]

na_values = [None]
abcd_sscep01 = read_abcd(path, cols, na_values)
# Out:
# meim_p_ss_exp                     n = 10076         mean = 3.1686
# meim_p_ss_com                     n = 10076         mean = 3.5041
# meim_p_ss_total                   n = 10076         mean = 3.3364
# via_p_ss_hc                       n = 7061          mean = 6.3347
# via_p_ss_amer                     n = 7061          mean = 6.8017
# nsc_p_ss_mean_3_items             n = 10700         mean = 3.8842
# fes_p_ss_fc_pr                    n = 10703         mean = 2.5260
# macv_p_ss_fs                      n = 10701         mean = 4.1643
# macv_p_ss_fo                      n = 10701         mean = 3.6362
# macv_p_ss_isr                     n = 10701         mean = 3.5607
# macv_p_ss_fr                      n = 10701         mean = 3.3941
# macv_p_ss_r                       n = 10701         mean = 3.3744
# psb_p_ss_mean                     n = 10685         mean = 1.7493
#
# subjects:     10707
# features:        13

# %% [markdown]
# # yacc01

# %%
path = r'E:\gregn\data\ABCD\abcd3\yacc01.txt'

cols = [
    'interview_age',
    'accult_q1_y',
    'accult_q2_y',
    'accult_q4_y',
    'accult_q5_y'
]

na_values = ['777', '999']
yacc01 = read_abcd(path, cols, na_values)
# Out:
# accult_q1_y                       n = 10688         mean = 3.7084
# accult_q2_y                       n = 10636         mean = 0.3717
# accult_q4_y                       n = 3953          mean = 4.4935
# accult_q5_y                       n = 3953          mean = 3.7797
#
# subjects:     10707
# features:         4

# %% [markdown]
# # pacc01

# %%
path = r'E:\gregn\data\ABCD\abcd3\pacc01.txt'

cols = [
    'interview_age',
    'accult_q1_p',
    'accult_q2_p',
    'accult_q4_p',
    'accult_q5_p'
]

na_values = ['777', '999']
pacc01 = read_abcd(path, cols, na_values)
# Out:
# accult_q1_p                       n = 10635         mean = 3.8062
# accult_q2_p                       n = 10702         mean = 0.3215
# accult_q4_p                       n = 3422          mean = 4.0190
# accult_q5_p                       n = 3427          mean = 3.7318
#
# subjects:     10707
# features:         4

# %% [markdown]
# # fhxp102

# %%
path = r'E:\gregn\data\ABCD\abcd3\fhxp102.txt'

cols = [
    'interview_age',
    'famhx_4d_p___0',
    'famhx_4d_p___1',
    'famhx_4d_p___2',
    'famhx_4d_p___3',
    'famhx_4d_p___7',
    'famhx_4d_p___4',
    'famhx_4d_p___5',
    'famhx_4d_p___6',
    'famhx4a_p___0',
    'famhx4a_p___1',
    'famhx4a_p___2',
    'famhx4a_p___3',
    'famhx4a_p___7',
    'famhx4a_p___4',
    'famhx4a_p___5',
    'famhx4a_p___6',
    'fam_history_q5a_drugs___0',
    'fam_history_q5a_drugs___1',
    'fam_history_q5a_drugs___2',
    'fam_history_q5a_drugs___3',
    'fam_history_q5a_drugs___7',
    'fam_history_q5a_drugs___4',
    'fam_history_q5a_drugs___5',
    'fam_history_q5a_drugs___6',
    'fam_history_q5d_drugs___0',
    'fam_history_q5d_drugs___1',
    'fam_history_q5d_drugs___2',
    'fam_history_q5d_drugs___3',
    'fam_history_q5d_drugs___7',
    'fam_history_q5d_drugs___4',
    'fam_history_q5d_drugs___5',
    'fam_history_q5d_drugs___6',
    'fam_history_q6a_depression',
    'fam_history_q6d_depression',
    'famhx_4d_p___999',
    'famhx4a_p___999',
    'fam_history_q5a_drugs___999',
    'fam_history_q5d_drugs___999',
    'famhx_4d_p___888'
    
]

na_values = ['999']
fhxp102 = read_abcd(path, cols, na_values)
# Out:
# famhx_4d_p___0                    n = 10707         mean = 0.3826
# famhx_4d_p___1                    n = 10707         mean = 0.0115
# famhx_4d_p___2                    n = 10707         mean = 0.0105
# famhx_4d_p___3                    n = 10707         mean = 0.0228
# famhx_4d_p___7                    n = 10707         mean = 0.0106
# famhx_4d_p___4                    n = 10707         mean = 0.0163
# famhx_4d_p___5                    n = 10707         mean = 0.0069
# famhx_4d_p___6                    n = 10707         mean = 0.0181
# famhx4a_p___0                     n = 10707         mean = 0.2971
# famhx4a_p___1                     n = 10707         mean = 0.0571
# famhx4a_p___2                     n = 10707         mean = 0.0420
# famhx4a_p___3                     n = 10707         mean = 0.0771
# famhx4a_p___7                     n = 10707         mean = 0.0341
# famhx4a_p___4                     n = 10707         mean = 0.0392
# famhx4a_p___5                     n = 10707         mean = 0.0164
# famhx4a_p___6                     n = 10707         mean = 0.0688
# fam_history_q5a_drugs___0         n = 10707         mean = 0.1996
# fam_history_q5a_drugs___1         n = 10707         mean = 0.0405
# fam_history_q5a_drugs___2         n = 10707         mean = 0.0429
# fam_history_q5a_drugs___3         n = 10707         mean = 0.0515
# fam_history_q5a_drugs___7         n = 10707         mean = 0.0300
# fam_history_q5a_drugs___4         n = 10707         mean = 0.0379
# fam_history_q5a_drugs___5         n = 10707         mean = 0.0188
# fam_history_q5a_drugs___6         n = 10707         mean = 0.0556
# fam_history_q5d_drugs___0         n = 10707         mean = 0.2558
# fam_history_q5d_drugs___1         n = 10707         mean = 0.0131
# fam_history_q5d_drugs___2         n = 10707         mean = 0.0181
# fam_history_q5d_drugs___3         n = 10707         mean = 0.0188
# fam_history_q5d_drugs___7         n = 10707         mean = 0.0155
# fam_history_q5d_drugs___4         n = 10707         mean = 0.0227
# fam_history_q5d_drugs___5         n = 10707         mean = 0.0102
# fam_history_q5d_drugs___6         n = 10707         mean = 0.0245
# fam_history_q6a_depression        n = 5227          mean = 0.2732
# fam_history_q6d_depression        n = 5473          mean = 0.4369
# famhx_4d_p___999                  n = 10707         mean = 0.0042
# famhx4a_p___999                   n = 10707         mean = 0.0124
# fam_history_q5a_drugs___999       n = 10707         mean = 0.0135
# fam_history_q5d_drugs___999       n = 10707         mean = 0.0031
# famhx_4d_p___888                  n = 10707         mean = 0.5638
#
# subjects:     10707
# features:        39

# %% [markdown]
# # fhxp201

# %%
path = r'E:\gregn\data\ABCD\abcd3\fhxp201.txt'

cols = [
    'interview_age',
    'fam_history_q7a_mania',
    'fam_history_q7d_mania',
    'fam_history_q8a_visions',
    'fam_history_q8d_visions',
    'fam_history_q9a_trouble',
    'fam_history_q9d_trouble',
    'fam_history_q10a_nerves',
    'fam_history_q10d_nerves',
    'fam_history_q11a_professional',
    'fam_history_q11d_professional',
    'fam_history_q12a_hospitalized',
    'fam_history_q12d_hospitalized',
    'fam_history_q13a_suicide',
    'fam_history_q13d_suicide'
]

na_values = ['999']
fhxp201 = read_abcd(path, cols, na_values)
# Out:
# fam_history_q7a_mania             n = 1342          mean = 0.2012
# fam_history_q7d_mania             n = 1402          mean = 0.1840
# fam_history_q8a_visions           n = 1042          mean = 0.1334
# fam_history_q8d_visions           n = 1078          mean = 0.0863
# fam_history_q9a_trouble           n = 3093          mean = 0.3993
# fam_history_q9d_trouble           n = 3154          mean = 0.1078
# fam_history_q10a_nerves           n = 2683          mean = 0.1837
# fam_history_q10d_nerves           n = 2796          mean = 0.3197
# fam_history_q11a_professional     n = 6162          mean = 0.3457
# fam_history_q11d_professional     n = 6389          mean = 0.5112
# fam_history_q12a_hospitalized     n = 3030          mean = 0.1515
# fam_history_q12d_hospitalized     n = 3142          mean = 0.1665
# fam_history_q13a_suicide          n = 1871          mean = 0.1261
# fam_history_q13d_suicide          n = 1939          mean = 0.1949
#
# subjects:     10707
# features:        14

# %% [markdown]
# # prq01

# %%
file_prq01 = r'E:\gregn\data\ABCD\abcd3\prq01.txt'
prq01 = pd.read_csv(file_prq01, sep='\t', index_col='subjectkey')
prq01 = prq01.drop(prq01.index[0])

cols = [
    'interview_age',
    'parent_rules_q1',
    'parent_rules_q1a',
    'parent_rules_q2',
    'parent_rules_q3',
    'parent_rules_q4',
    'parent_rules_q5',
    'parent_rules_q6',
    'parent_rules_q7',
    'parent_rules_q8',
    'parent_rules_q9',
]

for col in cols:
    prq01[col] = pd.to_numeric(prq01[col])
    prq01 = prq01[cols]
    
prq01 = pd.get_dummies(prq01, columns=[
    'parent_rules_q1',
    'parent_rules_q1a',
    'parent_rules_q3',
    'parent_rules_q4',
    'parent_rules_q5',
    'parent_rules_q6',
    'parent_rules_q7',
    'parent_rules_q8',
    'parent_rules_q9',
])

prq01['parent_rules_q1_allowed'] = (prq01['parent_rules_q1_2.0']
                                   + prq01['parent_rules_q1_3.0']
                                   + prq01['parent_rules_q1_4.0'])

prq01 = prq01.drop(columns=[
    'parent_rules_q1_2.0',
    'parent_rules_q1_3.0',
    'parent_rules_q1_4.0',
    'parent_rules_q4_2.0',
    'parent_rules_q4_3.0',
    'parent_rules_q4_4.0',
    'parent_rules_q4_5.0',
    'parent_rules_q4_6.0',
    'parent_rules_q7_2.0',
    'parent_rules_q7_3.0',
    'parent_rules_q7_4.0',
    'parent_rules_q7_5.0',
    'parent_rules_q7_6.0'
])

prq01 = prq01.reset_index()
prq01 = prq01.sort_values(['subjectkey', 'interview_age'])
prq01 = prq01.drop_duplicates(subset=['subjectkey'], keep='first')
prq01 = prq01.drop(columns=['interview_age'])
prq01 = prq01.set_index('subjectkey')

df_show = abcd_ysu02.join(prq01)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<40}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# parent_rules_q2                             n = 8269          mean = 0.6143        sum = 5080.0
# parent_rules_q1_1.0                         n = 10707         mean = 0.7576        sum = 8112
# parent_rules_q1_5.0                         n = 10707         mean = 0.0032        sum = 34
# parent_rules_q1_6.0                         n = 10707         mean = 0.2235        sum = 2393
# parent_rules_q1a_1.0                        n = 10707         mean = 0.0240        sum = 257
# parent_rules_q1a_2.0                        n = 10707         mean = 0.3229        sum = 3457
# parent_rules_q1a_3.0                        n = 10707         mean = 0.1797        sum = 1924
# parent_rules_q3_0.0                         n = 10707         mean = 0.0040        sum = 43
# parent_rules_q3_1.0                         n = 10707         mean = 0.1212        sum = 1298
# parent_rules_q3_4.0                         n = 10707         mean = 0.3492        sum = 3739
# parent_rules_q4_1.0                         n = 10707         mean = 0.8144        sum = 8720
# parent_rules_q5_1.0                         n = 10707         mean = 0.0177        sum = 189
# parent_rules_q5_2.0                         n = 10707         mean = 0.1847        sum = 1978
# parent_rules_q5_3.0                         n = 10707         mean = 0.6201        sum = 6639
# parent_rules_q6_0.0                         n = 10707         mean = 0.0405        sum = 434
# parent_rules_q6_1.0                         n = 10707         mean = 0.0060        sum = 64
# parent_rules_q6_2.0                         n = 10707         mean = 0.0084        sum = 90
# parent_rules_q6_3.0                         n = 10707         mean = 0.0296        sum = 317
# parent_rules_q6_4.0                         n = 10707         mean = 0.7379        sum = 7901
# parent_rules_q7_1.0                         n = 10707         mean = 0.7486        sum = 8015
# parent_rules_q8_1.0                         n = 10707         mean = 0.0129        sum = 138
# parent_rules_q8_2.0                         n = 10707         mean = 0.1111        sum = 1190
# parent_rules_q8_3.0                         n = 10707         mean = 0.6285        sum = 6729
# parent_rules_q9_1.0                         n = 10707         mean = 0.0361        sum = 386
# parent_rules_q9_2.0                         n = 10707         mean = 0.0055        sum = 59
# parent_rules_q9_3.0                         n = 10707         mean = 0.0060        sum = 64
# parent_rules_q9_4.0                         n = 10707         mean = 0.0294        sum = 315
# parent_rules_q9_5.0                         n = 10707         mean = 0.6755        sum = 7233
# parent_rules_q1_allowed                     n = 10707         mean = 0.0149        sum = 160
#
# subjects:     10707
# features:        29

# %% [markdown]
# # dhx01

# %%
path = r'E:\gregn\data\ABCD\abcd3\dhx01.txt'

cols = [ 
    'interview_age',
    'devhx_3_p',
    'devhx_4_p',
    'devhx_6_p',
    'devhx_7_p',
    'devhx_10',
    'devhx_10a3_p',
    'devhx_10b3_p',
    'devhx_10c3_p',
    'devhx_10d3_p',
    'devhx_10e3_p',
    'devhx_10f3_p',
    'devhx_10g3_p',
    'devhx_10h3_p',
    'devhx_10i3_p',
    'devhx_10j3_p',
    'devhx_10k3_p',
    'devhx_10l3_p',
    'devhx_10m3_p',
    'devhx_11_p', 
    'devhx_13_3_p',
    'devhx_14a3_p',
    'devhx_14b3_p',
    'devhx_14c3_p',
    'devhx_14d3_p',
    'devhx_14e3_p',
    'devhx_14f3_p',
    'devhx_14g3_p',
    'devhx_14h3_p',
    'devhx_15',
    'devhx_16_p',
    'devhx_17_p',
    'devhx_18_p',
    'devhx_19a_p',
    'devhx_19b_p',
    'devhx_19c_p',
    'devhx_19d_p',
    'devhx_20_p',
    'devhx_21_p',
    'devhx_22_3_p',
    'devhx_23b_p'
]

na_values = ['-1', '999']
dhx01 = read_abcd(path, cols, na_values)
# Out:
# devhx_3_p                         n = 10460         mean = 29.2909
# devhx_4_p                         n = 10111         mean = 31.7840
# devhx_6_p                         n = 10462         mean = 0.6082
# devhx_7_p                         n = 9428          mean = 6.9374
# devhx_10                          n = 10271         mean = 0.9538
# devhx_10a3_p                      n = 10352         mean = 0.1445
# devhx_10b3_p                      n = 10409         mean = 0.0452
# devhx_10c3_p                      n = 10354         mean = 0.0778
# devhx_10d3_p                      n = 10401         mean = 0.0112
# devhx_10e3_p                      n = 10336         mean = 0.0050
# devhx_10f3_p                      n = 10420         mean = 0.0015
# devhx_10g3_p                      n = 10363         mean = 0.0446
# devhx_10h3_p                      n = 10281         mean = 0.0772
# devhx_10i3_p                      n = 10371         mean = 0.0709
# devhx_10j3_p                      n = 10337         mean = 0.1019
# devhx_10k3_p                      n = 10378         mean = 0.0304
# devhx_10l3_p                      n = 10415         mean = 0.0185
# devhx_10m3_p                      n = 10392         mean = 0.0843
# devhx_11_p                        n = 9478          mean = 15.6823
# devhx_13_3_p                      n = 10569         mean = 0.3775
# devhx_14a3_p                      n = 10412         mean = 0.0315
# devhx_14b3_p                      n = 10397         mean = 0.0283
# devhx_14c3_p                      n = 10434         mean = 0.0471
# devhx_14d3_p                      n = 10501         mean = 0.0014
# devhx_14e3_p                      n = 10439         mean = 0.1635
# devhx_14f3_p                      n = 10436         mean = 0.0969
# devhx_14g3_p                      n = 10513         mean = 0.0048
# devhx_14h3_p                      n = 10334         mean = 0.0249
# devhx_15                          n = 10025         mean = 1.1604
# devhx_16_p                        n = 9534          mean = 1.3869
# devhx_17_p                        n = 9785          mean = 1.7927
# devhx_18_p                        n = 10297         mean = 7.6807
# devhx_19a_p                       n = 9419          mean = 4.0238
# devhx_19b_p                       n = 9374          mean = 7.7885
# devhx_19c_p                       n = 9934          mean = 13.7760
# devhx_19d_p                       n = 9134          mean = 11.1196
# devhx_20_p                        n = 10574         mean = 2.6293
# devhx_21_p                        n = 10585         mean = 2.7324
# devhx_22_3_p                      n = 10588         mean = 0.4603
# devhx_23b_p                       n = 4734          mean = 6.0714
#
# subjects:     10707
# features:        40

# %% [markdown]
# # birth weight

# %%
path = r'E:\gregn\data\ABCD\source\ABCD072120NonImaging\dhx01.txt'

cols = [
    'interview_age',
    'birth_weight_lbs',
    'birth_weight_oz'
]

na_values = [None]
birth_weight = read_abcd(path, cols, na_values)
# Out:
# birth_weight_lbs                  n = 10220         mean = 6.5868
# birth_weight_oz                   n = 9543          mean = 7.1381
#
# subjects:     10707
# features:         2

# %%
birth_weight['birth_weight'] = (birth_weight.birth_weight_lbs
                               + (birth_weight.birth_weight_oz * 0.0625))

birth_weight = birth_weight.drop(columns=['birth_weight_lbs', 'birth_weight_oz'])

# %% [markdown]
# # abcd_devhxss01

# %%
file_abcd_devhxss01 = r'E:\gregn\data\ABCD\abcd3\abcd_devhxss01.txt'

abcd_devhxss01 = pd.read_csv(file_abcd_devhxss01, sep='\t', index_col='subjectkey', na_values=999)
abcd_devhxss01 = abcd_devhxss01.drop(abcd_devhxss01.index[0])

cols = [
    'interview_age',
    'devhx_ss_8_cigs_per_day_p',
    'devhx_ss_8_alcohol_max_p',
    'devhx_ss_8_alcohol_avg_p',
    'devhx_ss_8_alcohol_effects_p',
    'devhx_ss_8_marijuana_amt_p',
    'devhx_ss_8_coc_crack_amt_p',
    'devhx_ss_8_her_morph_amt_p',
    'devhx_ss_8_oxycont_amt_p',
    'devhx_ss_9_cigs_per_day_p',
    'devhx_ss_9_alcohol_max_p',
    'devhx_ss_9_alcohol_avg_p',
    'devhx_ss_9_alcohol_effects_p',
    'devhx_ss_9_marijuana_amt_p',
    'devhx_ss_9_coc_crack_amt_p',
    'devhx_ss_9_her_morph_amt_p',
    'devhx_ss_9_oxycont_amt_p',
    'devhx_ss_12_p'
]

for col in cols:
    abcd_devhxss01[col] = pd.to_numeric(abcd_devhxss01[col])
    abcd_devhxss01 = abcd_devhxss01[cols]
    
abcd_devhxss01 = abcd_devhxss01.reset_index()
abcd_devhxss01 = abcd_devhxss01.sort_values(['subjectkey', 'interview_age'])
abcd_devhxss01 = abcd_devhxss01.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_devhxss01 = abcd_devhxss01.drop(columns=['interview_age'])
abcd_devhxss01 = abcd_devhxss01.set_index('subjectkey')

abcd_devhxss01['devhx_ss_coc_crack_amt_p'] = (abcd_devhxss01.devhx_ss_8_coc_crack_amt_p
                                              + abcd_devhxss01.devhx_ss_9_coc_crack_amt_p) / 2

abcd_devhxss01['devhx_ss_her_morph_oxycont_amt_p'] = (abcd_devhxss01.devhx_ss_8_her_morph_amt_p
                                                      + abcd_devhxss01.devhx_ss_9_her_morph_amt_p
                                                      + abcd_devhxss01.devhx_ss_8_oxycont_amt_p
                                                      + abcd_devhxss01.devhx_ss_9_oxycont_amt_p) / 4


abcd_devhxss01 = abcd_devhxss01.drop(columns=[
    'devhx_ss_8_coc_crack_amt_p',
    'devhx_ss_9_coc_crack_amt_p',
    'devhx_ss_8_her_morph_amt_p',
    'devhx_ss_9_her_morph_amt_p',
    'devhx_ss_8_oxycont_amt_p',
    'devhx_ss_9_oxycont_amt_p'
])

df_show = abcd_ysu02.join(abcd_devhxss01)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<40}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# devhx_ss_8_cigs_per_day_p                   n = 10289         mean = 1.0220        sum = 10515.5
# devhx_ss_8_alcohol_max_p                    n = 9792          mean = 0.5376        sum = 5264.5
# devhx_ss_8_alcohol_avg_p                    n = 9761          mean = 0.8746        sum = 8536.529999999999
# devhx_ss_8_alcohol_effects_p                n = 9637          mean = 0.4397        sum = 4237.75
# devhx_ss_8_marijuana_amt_p                  n = 10212         mean = 0.0883        sum = 902.0799999999999
# devhx_ss_9_cigs_per_day_p                   n = 10360         mean = 0.3194        sum = 3308.5
# devhx_ss_9_alcohol_max_p                    n = 10382         mean = 0.0287        sum = 298.0
# devhx_ss_9_alcohol_avg_p                    n = 10377         mean = 0.0446        sum = 462.66999999999996
# devhx_ss_9_alcohol_effects_p                n = 10347         mean = 0.0326        sum = 337.25
# devhx_ss_9_marijuana_amt_p                  n = 10364         mean = 0.0250        sum = 258.89
# devhx_ss_12_p                               n = 10552         mean = 0.9206        sum = 9714.0
# devhx_ss_coc_crack_amt_p                    n = 10374         mean = 0.0039        sum = 40.0
# devhx_ss_her_morph_oxycont_amt_p            n = 10376         mean = 0.0011        sum = 11.75
#
# subjects:     10707
# features:        13

# %% [markdown]
# # acspsw03

# %%
path = r'E:\gregn\data\ABCD\abcd3\acspsw03.txt'

cols = [
    'interview_age',
    'rel_family_id',
    'acs_raked_propensity_score'
]

na_values = [None]
acspsw03 = read_abcd(path, cols, na_values)
# Out:
# rel_family_id                     n = 10707         mean = 5921.1416
# acs_raked_propensity_score        n = 10707         mean = 690.4637
#
# subjects:     10707
# features:         2

# %% [markdown]
# # abcd_saiq02

# %%
file_abcd_saiq02 = r'E:\gregn\data\ABCD\abcd3\abcd_saiq02.txt'
abcd_saiq02 = pd.read_csv(file_abcd_saiq02, sep='\t', index_col='subjectkey')
abcd_saiq02 = abcd_saiq02.drop(abcd_saiq02.index[0])

cols = [
    'interview_age',
    'sai_p_activities___0',
    'sai_p_activities___1',
    'sai_p_activities___2',
    'sai_p_activities___3',
    'sai_p_activities___4',
    'sai_p_activities___5',
    'sai_p_activities___6',
    'sai_p_activities___7',
    'sai_p_activities___8',
    'sai_p_activities___9',
    'sai_p_activities___10',
    'sai_p_activities___11',
    'sai_p_activities___12',
    'sai_p_activities___13',
    'sai_p_activities___14',
    'sai_p_activities___15',
    'sai_p_activities___16',
    'sai_p_activities___17',
    'sai_p_activities___18',
    'sai_p_activities___19',
    'sai_p_activities___20',
    'sai_p_activities___21',
    'sai_p_activities___22',
    'sai_p_activities___23',
    'sai_p_activities___24',
    'sai_p_activities___25',
    'sai_p_activities___26',
    'sai_p_activities___27',
    'sai_p_activities___28',
    'sai_p_activities___29'
]

for col in cols:
    abcd_saiq02[col] = pd.to_numeric(abcd_saiq02[col])
    abcd_saiq02 = abcd_saiq02[cols]
    
    
abcd_saiq02 = abcd_saiq02.reset_index()
abcd_saiq02 = abcd_saiq02.sort_values(['subjectkey', 'interview_age'])
abcd_saiq02 = abcd_saiq02.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_saiq02 = abcd_saiq02.drop(columns=['interview_age'])
abcd_saiq02 = abcd_saiq02.set_index('subjectkey')

abcd_saiq02['sai_involvement_sum'] = abcd_saiq02.sum(axis=1)
abcd_saiq02 = abcd_saiq02.iloc[:, -1]

df = abcd_saiq02
print('sai_involvement_sum     n = {:<10}    mean = {:<10.4f}'.\
      format( abcd_saiq02.notnull().sum(), abcd_saiq02.mean()))
# Out:
# sai_involvement_sum     n = 11878         mean = 3.6637

# %% [markdown]
# # abcd_ssmty01

# %%
path = r'E:\gregn\data\ABCD\abcd3\abcd_ssmty01.txt'

cols = [
    'interview_age',
    'stq_y_ss_weekday',
    'stq_y_ss_weekend'
]

na_values = [None]
abcd_ssmty01 = read_abcd(path, cols, na_values)
# Out:
# stq_y_ss_weekday                  n = 10685         mean = 3.4637
# stq_y_ss_weekend                  n = 10684         mean = 4.6037
#
# subjects:     10707
# features:         2

# %% [markdown]
# # abcd_lt01

# %%
file_abcd_lt01 = r'E:\gregn\data\ABCD\abcd3\abcd_lt01.txt'

abcd_lt01 = pd.read_csv(file_abcd_lt01, sep='\t', index_col='subjectkey')
abcd_lt01 = abcd_lt01.drop(abcd_lt01.index[0])

cols = [
    'interview_age',
    'site_id_l'
]

abcd_lt01 = pd.get_dummies(abcd_lt01, columns=['site_id_l'])

abcd_lt01 = abcd_lt01.reset_index()
abcd_lt01 = abcd_lt01.sort_values(['subjectkey', 'interview_age'])
abcd_lt01 = abcd_lt01.drop_duplicates(subset=['subjectkey'], keep='first')
abcd_lt01 = abcd_lt01.drop(columns=['interview_age'])
abcd_lt01 = abcd_lt01.set_index('subjectkey')

abcd_lt01 = abcd_lt01.iloc[:, 8:]

df_show = abcd_ysu02.join(abcd_lt01)
df_show = df_show.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn'
])

for col in df_show.columns:
    print('{:<40}    n = {:<10}    mean = {:<10.4f}    sum = {:<10}'.\
          format(col,  df_show[col].notnull().sum(), df_show[col].mean(), df_show[col].sum()))    
print('\nsubjects:{:>10}\nfeatures:{:>10}'.format(df_show.shape[0], df_show.shape[1]))
# Out:
# site_id_l_site01                            n = 10707         mean = 0.0345        sum = 369
# site_id_l_site02                            n = 10707         mean = 0.0468        sum = 501
# site_id_l_site03                            n = 10707         mean = 0.0531        sum = 569
# site_id_l_site04                            n = 10707         mean = 0.0616        sum = 660
# site_id_l_site05                            n = 10707         mean = 0.0311        sum = 333
# site_id_l_site06                            n = 10707         mean = 0.0497        sum = 532
# site_id_l_site07                            n = 10707         mean = 0.0280        sum = 300
# site_id_l_site08                            n = 10707         mean = 0.0289        sum = 309
# site_id_l_site09                            n = 10707         mean = 0.0357        sum = 382
# site_id_l_site10                            n = 10707         mean = 0.0616        sum = 660
# site_id_l_site11                            n = 10707         mean = 0.0389        sum = 416
# site_id_l_site12                            n = 10707         mean = 0.0511        sum = 547
# site_id_l_site13                            n = 10707         mean = 0.0609        sum = 652
# site_id_l_site14                            n = 10707         mean = 0.0511        sum = 547
# site_id_l_site15                            n = 10707         mean = 0.0399        sum = 427
# site_id_l_site16                            n = 10707         mean = 0.0910        sum = 974
# site_id_l_site17                            n = 10707         mean = 0.0472        sum = 505
# site_id_l_site18                            n = 10707         mean = 0.0309        sum = 331
# site_id_l_site19                            n = 10707         mean = 0.0468        sum = 501
# site_id_l_site20                            n = 10707         mean = 0.0591        sum = 633
# site_id_l_site21                            n = 10707         mean = 0.0494        sum = 529
# site_id_l_site22                            n = 10707         mean = 0.0028        sum = 30
#
# subjects:     10707
# features:        22

# %% [markdown]
# # join dataframes

# %%
dfs = [
    abcd_ysu02,
    abcd_asrs01,
    abcd_rhds01,
    abcd_fes01,
    fes02,
    abcd_ptsd01,
    abcd_crpf01,
    pmq01,
    crpbi01,
    pdem02,
    abcd_meim01,
    abcd_sscep01,
    yacc01,
    pacc01,
    fhxp102,
    fhxp201,
    prq01,
    dhx01, 
    birth_weight,
    abcd_devhxss01,
    acspsw03,
    abcd_saiq02, 
    abcd_ssmty01,
    abcd_lt01,
]

abcd = dfs[0].join(dfs[1:])
print('number of subjects:', len(abcd))
# Out:
# number of subjects: 10707

# %% [markdown]
# # X features

# %%
X = abcd.drop(columns=[
    'isip_1d_2',
    'isip_5_2',
    'isip_1b_yn',
    'rel_family_id'
])
print('number of features:', X.shape[1])
list(X.columns)
# Out:
# number of features: 341
# ['asr_scr_perstr_t',
#  'asr_scr_anxdep_t',
#  'asr_scr_withdrawn_t',
#  'asr_scr_somatic_t',
#  'asr_scr_thought_t',
#  'asr_scr_attention_t',
#  'asr_scr_aggressive_t',
#  'asr_scr_rulebreak_t',
#  'asr_scr_intrusive_t',
#  'asr_scr_internal_t',
#  'asr_scr_external_t',
#  'asr_scr_totprob_t',
#  'asr_scr_depress_t',
#  'asr_scr_anxdisord_t',
#  'asr_scr_somaticpr_t',
#  'asr_scr_avoidant_t',
#  'asr_scr_adhd_t',
#  'asr_scr_antisocial_t',
#  'asr_scr_inattention_t',
#  'asr_scr_hyperactive_t',
#  'reshist_addr1_years',
#  'reshist_addr1_elevation',
#  'reshist_addr1_d1a',
#  'reshist_addr1_walkindex',
#  'reshist_addr1_grndtot',
#  'reshist_addr1_p1tot',
#  'reshist_addr1_p1vlnt',
#  'reshist_addr1_drugtot',
#  'reshist_addr1_drgsale',
#  'reshist_addr1_mjsale',
#  'reshist_addr1_drgposs',
#  'reshist_addr1_dui',
#  'reshist_addr1_adi_edu_l',
#  'reshist_addr1_adi_edu_h',
#  'reshist_addr1_adi_work_c',
#  'reshist_addr1_adi_income',
#  'reshist_addr1_adi_in_dis',
#  'reshist_addr1_adi_home_v',
#  'reshist_addr1_adi_rent',
#  'reshist_addr1_adi_mortg',
#  'reshist_addr1_adi_home_o',
#  'reshist_addr1_adi_crowd',
#  'reshist_addr1_adi_unemp',
#  'reshist_addr1_adi_pov',
#  'reshist_addr1_adi_b138',
#  'reshist_addr1_adi_sp',
#  'reshist_addr1_adi_ncar',
#  'reshist_addr1_adi_ntel',
#  'reshist_addr1_adi_nplumb',
#  'reshist_addr1_adi_wsum',
#  'reshist_addr1_adi_perc',
#  'reshist_addr1_popdensity',
#  'reshist_addr1_no2',
#  'reshist_addr1_pm25',
#  'reshist_addr1_proxrd',
#  'reshist_addr1_pm252016aa',
#  'reshist_addr1_leadrisk_poverty',
#  'reshist_addr1_leadrisk_housing',
#  'reshist_addr1_leadrisk',
#  'fes_youth_q1',
#  'fes_youth_q2',
#  'fes_youth_q3',
#  'fes_youth_q4',
#  'fes_youth_q5',
#  'fes_youth_q6',
#  'fes_youth_q7',
#  'fes_youth_q8',
#  'fes_youth_q9',
#  'fam_enviro1_p',
#  'fam_enviro2r_p',
#  'fam_enviro3_p',
#  'fam_enviro4r_p',
#  'fam_enviro5_p',
#  'fam_enviro6_p',
#  'fam_enviro7r_p',
#  'fam_enviro8_p',
#  'fam_enviro9r_p',
#  'ksads_ptsd_home',
#  'ksads_ptsd_outside_home',
#  'su_risk_p_1',
#  'su_risk_p_2',
#  'su_risk_p_3',
#  'su_risk_p_4',
#  'su_risk_p_5',
#  'su_risk_p_6',
#  'su_risk_p_7',
#  'su_risk_p_8',
#  'su_risk_p_9',
#  'parent_monitor_q1_y',
#  'parent_monitor_q2_y',
#  'parent_monitor_q3_y',
#  'parent_monitor_q4_y',
#  'parent_monitor_q5_y',
#  'crpbi_parent1_y',
#  'crpbi_parent2_y',
#  'crpbi_parent3_y',
#  'crpbi_parent4_y',
#  'crpbi_parent5_y',
#  'crpbi_caregiver1_y',
#  'demo_adopt_agex_v2',
#  'demo_prnt_age_v2',
#  'demo_prnt_ed_v2',
#  'demo_prnt_empl_time',
#  'demo_prnt_income_v2',
#  'demo_prnt_prtnr_v2',
#  'demo_comb_income_v2',
#  'demo_fam_exp1_v2',
#  'demo_fam_exp2_v2',
#  'demo_fam_exp3_v2',
#  'demo_fam_exp4_v2',
#  'demo_fam_exp5_v2',
#  'demo_fam_exp6_v2',
#  'demo_fam_exp7_v2',
#  'demo_prim_biological_mother',
#  'demo_prim_biological_father',
#  'demo_prim_adoptive_parent',
#  'demo_prim_custodial_parent',
#  'demo_prim_other',
#  'demo_sex_v2_male',
#  'demo_sex_v2_female',
#  'demo_gender_id_v2_male',
#  'demo_gender_id_v2_female',
#  'demo_prnt_gender_id_v2_male',
#  'demo_prnt_gender_id_v2_female',
#  'demo_prnt_marital_v2_married',
#  'demo_prnt_marital_v2_widowed',
#  'demo_prnt_marital_v2_divorced',
#  'demo_prnt_marital_v2_separated',
#  'demo_prnt_marital_v2_never_married',
#  'demo_prnt_marital_v2_living_with_partner',
#  'demo_prnt_empl_v2_working_now',
#  'demo_prnt_empl_v2_temporarily_laid_off',
#  'demo_prnt_empl_v2_looking_for_work',
#  'demo_prnt_empl_v2_retired',
#  'demo_prnt_empl_v2_disabled',
#  'demo_prnt_empl_v2_stay_at_home_parent',
#  'demo_prnt_empl_v2_student',
#  'demo_prnt_empl_v2_other',
#  'demo_prnt_empl_v2_sick_leave',
#  'demo_prnt_empl_v2_maternity_leave',
#  'demo_prnt_empl_v2_unemployed_not_looking',
#  'demo_gender_id_v2_non-binary',
#  'demo_prnt_gender_id_v2_non-binary',
#  'meim_ethnic_id_p_none',
#  'meim_ethnic_id_p_white/caucasian',
#  'meim_ethnic_id_p_western_european',
#  'meim_ethnic_id_p_eastern_european',
#  'meim_ethnic_id_p_hispanic/latino',
#  'meim_ethnic_id_p_black/african_american',
#  'meim_ethnic_id_p_afro-carribean/indo-carribbean/west_indian',
#  'meim_ethnic_id_p_east_asian',
#  'meim_ethnic_id_p_south_asian',
#  'meim_ethnic_id_p_southeast_asian',
#  'meim_ethnic_id_p_american_indian/alaska_native',
#  'meim_ethnic_id_p_middle_eastern/north_african',
#  'meim_ethnic_id_p_native_hawaiian_or_pacific_islander',
#  'meim_ethnic_id_p_mixed',
#  'meim_ethnic_id_p_other',
#  'meim_p_ss_exp',
#  'meim_p_ss_com',
#  'meim_p_ss_total',
#  'via_p_ss_hc',
#  'via_p_ss_amer',
#  'nsc_p_ss_mean_3_items',
#  'fes_p_ss_fc_pr',
#  'macv_p_ss_fs',
#  'macv_p_ss_fo',
#  'macv_p_ss_isr',
#  'macv_p_ss_fr',
#  'macv_p_ss_r',
#  'psb_p_ss_mean',
#  'accult_q1_y',
#  'accult_q2_y',
#  'accult_q4_y',
#  'accult_q5_y',
#  'accult_q1_p',
#  'accult_q2_p',
#  'accult_q4_p',
#  'accult_q5_p',
#  'famhx_4d_p___0',
#  'famhx_4d_p___1',
#  'famhx_4d_p___2',
#  'famhx_4d_p___3',
#  'famhx_4d_p___7',
#  'famhx_4d_p___4',
#  'famhx_4d_p___5',
#  'famhx_4d_p___6',
#  'famhx4a_p___0',
#  'famhx4a_p___1',
#  'famhx4a_p___2',
#  'famhx4a_p___3',
#  'famhx4a_p___7',
#  'famhx4a_p___4',
#  'famhx4a_p___5',
#  'famhx4a_p___6',
#  'fam_history_q5a_drugs___0',
#  'fam_history_q5a_drugs___1',
#  'fam_history_q5a_drugs___2',
#  'fam_history_q5a_drugs___3',
#  'fam_history_q5a_drugs___7',
#  'fam_history_q5a_drugs___4',
#  'fam_history_q5a_drugs___5',
#  'fam_history_q5a_drugs___6',
#  'fam_history_q5d_drugs___0',
#  'fam_history_q5d_drugs___1',
#  'fam_history_q5d_drugs___2',
#  'fam_history_q5d_drugs___3',
#  'fam_history_q5d_drugs___7',
#  'fam_history_q5d_drugs___4',
#  'fam_history_q5d_drugs___5',
#  'fam_history_q5d_drugs___6',
#  'fam_history_q6a_depression',
#  'fam_history_q6d_depression',
#  'famhx_4d_p___999',
#  'famhx4a_p___999',
#  'fam_history_q5a_drugs___999',
#  'fam_history_q5d_drugs___999',
#  'famhx_4d_p___888',
#  'fam_history_q7a_mania',
#  'fam_history_q7d_mania',
#  'fam_history_q8a_visions',
#  'fam_history_q8d_visions',
#  'fam_history_q9a_trouble',
#  'fam_history_q9d_trouble',
#  'fam_history_q10a_nerves',
#  'fam_history_q10d_nerves',
#  'fam_history_q11a_professional',
#  'fam_history_q11d_professional',
#  'fam_history_q12a_hospitalized',
#  'fam_history_q12d_hospitalized',
#  'fam_history_q13a_suicide',
#  'fam_history_q13d_suicide',
#  'parent_rules_q2',
#  'parent_rules_q1_1.0',
#  'parent_rules_q1_5.0',
#  'parent_rules_q1_6.0',
#  'parent_rules_q1a_1.0',
#  'parent_rules_q1a_2.0',
#  'parent_rules_q1a_3.0',
#  'parent_rules_q3_0.0',
#  'parent_rules_q3_1.0',
#  'parent_rules_q3_4.0',
#  'parent_rules_q4_1.0',
#  'parent_rules_q5_1.0',
#  'parent_rules_q5_2.0',
#  'parent_rules_q5_3.0',
#  'parent_rules_q6_0.0',
#  'parent_rules_q6_1.0',
#  'parent_rules_q6_2.0',
#  'parent_rules_q6_3.0',
#  'parent_rules_q6_4.0',
#  'parent_rules_q7_1.0',
#  'parent_rules_q8_1.0',
#  'parent_rules_q8_2.0',
#  'parent_rules_q8_3.0',
#  'parent_rules_q9_1.0',
#  'parent_rules_q9_2.0',
#  'parent_rules_q9_3.0',
#  'parent_rules_q9_4.0',
#  'parent_rules_q9_5.0',
#  'parent_rules_q1_allowed',
#  'devhx_3_p',
#  'devhx_4_p',
#  'devhx_6_p',
#  'devhx_7_p',
#  'devhx_10',
#  'devhx_10a3_p',
#  'devhx_10b3_p',
#  'devhx_10c3_p',
#  'devhx_10d3_p',
#  'devhx_10e3_p',
#  'devhx_10f3_p',
#  'devhx_10g3_p',
#  'devhx_10h3_p',
#  'devhx_10i3_p',
#  'devhx_10j3_p',
#  'devhx_10k3_p',
#  'devhx_10l3_p',
#  'devhx_10m3_p',
#  'devhx_11_p',
#  'devhx_13_3_p',
#  'devhx_14a3_p',
#  'devhx_14b3_p',
#  'devhx_14c3_p',
#  'devhx_14d3_p',
#  'devhx_14e3_p',
#  'devhx_14f3_p',
#  'devhx_14g3_p',
#  'devhx_14h3_p',
#  'devhx_15',
#  'devhx_16_p',
#  'devhx_17_p',
#  'devhx_18_p',
#  'devhx_19a_p',
#  'devhx_19b_p',
#  'devhx_19c_p',
#  'devhx_19d_p',
#  'devhx_20_p',
#  'devhx_21_p',
#  'devhx_22_3_p',
#  'devhx_23b_p',
#  'birth_weight',
#  'devhx_ss_8_cigs_per_day_p',
#  'devhx_ss_8_alcohol_max_p',
#  'devhx_ss_8_alcohol_avg_p',
#  'devhx_ss_8_alcohol_effects_p',
#  'devhx_ss_8_marijuana_amt_p',
#  'devhx_ss_9_cigs_per_day_p',
#  'devhx_ss_9_alcohol_max_p',
#  'devhx_ss_9_alcohol_avg_p',
#  'devhx_ss_9_alcohol_effects_p',
#  'devhx_ss_9_marijuana_amt_p',
#  'devhx_ss_12_p',
#  'devhx_ss_coc_crack_amt_p',
#  'devhx_ss_her_morph_oxycont_amt_p',
#  'acs_raked_propensity_score',
#  'sai_involvement_sum',
#  'stq_y_ss_weekday',
#  'stq_y_ss_weekend',
#  'site_id_l_site01',
#  'site_id_l_site02',
#  'site_id_l_site03',
#  'site_id_l_site04',
#  'site_id_l_site05',
#  'site_id_l_site06',
#  'site_id_l_site07',
#  'site_id_l_site08',
#  'site_id_l_site09',
#  'site_id_l_site10',
#  'site_id_l_site11',
#  'site_id_l_site12',
#  'site_id_l_site13',
#  'site_id_l_site14',
#  'site_id_l_site15',
#  'site_id_l_site16',
#  'site_id_l_site17',
#  'site_id_l_site18',
#  'site_id_l_site19',
#  'site_id_l_site20',
#  'site_id_l_site21',
#  'site_id_l_site22']

# %% [markdown]
# # family groups

# %%
from collections import defaultdict

d = defaultdict(lambda: len(d))
family_groups = [d[x] for x in abcd['rel_family_id']]
family_groups = np.array(family_groups)

# %% [markdown]
# # nested cross validation

# %%
import xgboost
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, GroupKFold
from time import time
from datetime import timedelta
warnings.filterwarnings('ignore')

start_time = time()


model = XGBClassifier(
    tree_method = 'gpu_hist',
    objective = 'binary:logistic',
    eval_metric = 'auc',
    random_state = 42
)


params = {
    'learning_rate': [0.005, 0.01, 0.1],
    'max_depth': [4, 6, 8],
    'n_estimators': [100, 500, 1000, 1500, 2000, 2500],
    'colsample_bytree': [0.4, 0.8]
}


inner_cv = GroupKFold(n_splits=5)
inner_cv = inner_cv.get_n_splits(X, y, groups=family_groups.tolist())
    
outer_cv = GroupKFold(n_splits=5)
outer_cv = outer_cv.get_n_splits(X, y, groups=family_groups.tolist())
    
    
# non_nested parameter search and scoring
gs = GridSearchCV(
    estimator=model, 
    param_grid=params, 
    scoring='roc_auc', 
    cv=inner_cv,
    return_train_score=True,
    verbose=3
)


gs.fit(X,y)

nested_score = cross_val_score(
    gs,
    X=X, 
    y=y, 
    scoring='roc_auc', 
    cv=outer_cv,
)
print('-------------------------------------------------------------------------------')
print('\nruntime:', str(timedelta(seconds=time()-start_time)))
print('scores:', nested_score)
print('average score:', nested_score.mean())
print('std:', nested_score.std())
print('\nbest estimator:\n\n', gs.best_estimator_)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   4.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   4.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   4.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   4.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   4.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   6.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   6.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   6.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   6.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   7.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=   8.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=   8.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=   8.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=   8.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=   8.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  10.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  10.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  10.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  10.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  10.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   5.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   5.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   5.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   5.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   5.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=   9.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=   9.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=   9.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=   9.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=  10.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  13.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  13.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  13.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  14.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  16.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  17.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  17.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  18.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  17.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  17.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  21.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  21.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  20.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  21.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  22.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   2.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   2.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   2.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   2.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   2.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  12.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  12.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  12.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  12.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  12.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  23.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  21.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  21.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  23.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  22.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  30.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  28.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  29.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  29.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  29.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  36.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  35.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  36.4s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  38.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  37.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  43.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  43.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  43.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  45.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  44.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   4.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   4.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   4.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   4.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   4.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   6.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   6.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   6.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   6.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   6.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=   7.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=   8.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=   7.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=   8.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=   8.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=   9.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  10.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  10.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  10.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  10.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   5.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   5.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   4.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   5.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   5.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   8.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   8.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   8.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   9.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   8.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  12.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  12.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  12.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  12.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  12.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  16.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  16.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  16.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  16.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  17.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  19.8s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  20.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  20.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  20.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  20.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   2.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   2.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   2.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   2.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   2.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  11.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  11.1s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  11.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  11.1s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  11.2s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  18.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  17.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  17.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  18.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  18.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  25.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  24.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  25.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  26.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  25.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  33.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  32.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  33.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  34.6s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  32.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  40.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  39.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  40.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  42.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  39.8s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   3.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   5.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   6.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   5.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   6.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   6.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   7.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   8.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   8.1s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   7.9s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   8.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=   9.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=   9.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=   9.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=  10.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=  10.1s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   4.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   4.2s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   4.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   4.3s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   4.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   7.6s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   7.6s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   7.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   7.7s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   7.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  10.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  10.9s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  10.8s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  10.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  10.6s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  13.4s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  14.5s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  14.5s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  13.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  13.4s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  15.7s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  15.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  15.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  16.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  15.7s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   1.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   1.8s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   1.9s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   2.0s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   1.9s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   7.1s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   7.0s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   7.0s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   7.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   7.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  12.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  11.7s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  11.3s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  11.8s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  12.3s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  15.0s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  15.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  16.7s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  15.5s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  14.5s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  17.9s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  17.4s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  17.6s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  17.2s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  17.0s
# [CV 1/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  19.3s
# [CV 2/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  19.3s
# [CV 3/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  19.2s
# [CV 4/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  19.4s
# [CV 5/5] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  19.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=500; total time=   2.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   5.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   5.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   6.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   5.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1000; total time=   5.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   8.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   8.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   8.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   8.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=1500; total time=   8.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=  11.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=  11.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=  10.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=  10.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2000; total time=  10.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  12.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  13.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  13.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  13.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=4, n_estimators=2500; total time=  13.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=100; total time=   1.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   7.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   7.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   7.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   7.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=500; total time=   7.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=  13.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=  13.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=  13.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=  14.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1000; total time=  13.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  19.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  18.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  19.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  19.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=1500; total time=  19.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  24.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  24.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  24.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  25.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2000; total time=  24.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  29.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  29.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  29.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  31.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=6, n_estimators=2500; total time=  30.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   3.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   3.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   3.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   4.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=100; total time=   3.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  17.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  17.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  17.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  18.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=500; total time=  17.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  33.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  32.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  31.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  30.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1000; total time=  30.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  41.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  38.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  39.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  41.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=1500; total time=  41.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  50.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  48.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  50.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  52.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2000; total time=  52.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  58.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  57.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2500; total time=  59.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2500; total time= 1.0min
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.005, max_depth=8, n_estimators=2500; total time= 1.0min
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   2.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   5.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   5.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   5.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   5.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   5.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   7.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   7.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   7.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   7.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=1500; total time=   8.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=   9.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=  10.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=  10.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=  10.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2000; total time=  10.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  12.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  12.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  12.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  12.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=4, n_estimators=2500; total time=  12.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   7.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.8s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  12.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  12.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  17.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  16.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  17.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  18.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  17.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  21.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  22.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  24.2s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  23.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  22.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  27.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  27.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  28.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  28.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  28.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  15.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  15.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  14.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  15.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  15.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  25.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  24.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  24.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  26.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  25.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  35.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  34.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  35.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  37.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  37.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  46.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  45.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  46.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  49.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  48.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  55.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  55.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  56.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time= 1.0min
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  59.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.6s
# ...
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   6.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=  11.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  16.6s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  16.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  16.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  16.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=1500; total time=  16.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  21.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  20.9s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  21.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  22.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2000; total time=  21.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  27.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  27.0s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  27.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  26.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=6, n_estimators=2500; total time=  26.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   3.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  14.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  14.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  13.7s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  13.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=500; total time=  14.0s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  23.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  24.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  23.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  23.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=  24.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  34.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  33.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  33.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  33.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=1500; total time=  35.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  44.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  43.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  43.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  43.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2000; total time=  45.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  53.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  52.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  50.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  52.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.01, max_depth=8, n_estimators=2500; total time=  54.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   2.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.7s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   4.7s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   7.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   7.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   7.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   7.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=1500; total time=   7.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   9.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   9.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   9.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   9.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2000; total time=   9.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=  11.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=  11.5s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=  11.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=  11.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=4, n_estimators=2500; total time=  11.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   1.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   5.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   5.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   5.4s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   5.3s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   5.4s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   9.3s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   9.4s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   9.3s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   9.4s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   9.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  12.7s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  12.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  12.8s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  12.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=1500; total time=  13.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  15.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  15.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  15.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  16.0s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2000; total time=  15.6s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  17.9s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  18.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  18.0s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  17.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=6, n_estimators=2500; total time=  17.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   2.5s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   2.6s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   2.5s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   2.6s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   2.5s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   8.8s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   8.7s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   8.6s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   8.8s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=500; total time=   9.1s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  13.1s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  13.2s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  13.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  13.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=  13.2s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  16.4s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  16.3s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  16.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  16.2s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=1500; total time=  16.3s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  19.0s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  18.8s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  18.9s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  18.9s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2000; total time=  18.9s
# [CV 1/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  21.2s
# [CV 2/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  21.1s
# [CV 3/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  21.1s
# [CV 4/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  21.1s
# [CV 5/5] END colsample_bytree=0.8, learning_rate=0.1, max_depth=8, n_estimators=2500; total time=  21.1s
# -------------------------------------------------------------------------------
#
# runtime: 11:47:54.453571
# scores: [0.75775425 0.76674448 0.75640299 0.73799745 0.75830708]
# average score: 0.7554412514450145
# std: 0.009450259938867474
#
# best estimator:
#
#  XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.4, eval_metric='auc',
#               gamma=0, gpu_id=0, importance_type='gain',
#               interaction_constraints='', learning_rate=0.005, max_delta_step=0,
#               max_depth=8, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=1000, n_jobs=12,
#               num_parallel_tree=1, random_state=42, reg_alpha=0, reg_lambda=1,
#               scale_pos_weight=1, subsample=1, tree_method='gpu_hist',
#               validate_parameters=1, verbosity=None)

# %%
import joblib
joblib.dump(gs, 'abcd3_sip10_environmental_gridsearch.pkl')
joblib.dump(nested_score, 'abcd3_sip10_environmental_nested_score.pkl')
# Out:
# ['abcd3_sip10_environmental_nested_score.pkl']

# %% [markdown]
# # SHAP

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
explainer = shap.TreeExplainer(gs.best_estimator_)
shap_values = explainer.shap_values(X)

X_display, y_display = X, y

# %%
# feature importance
vals_mean= np.abs(shap_values).mean(0)
vals_std= np.abs(shap_values).std(0)

feature_importance = pd.DataFrame(list(zip(X.columns, vals_mean, vals_std)), 
                                  columns=['feature','importance', 'std'])
feature_importance.sort_values(by=['importance'], ascending=False, inplace=True)
with pd.option_context('display.max_rows', None):
    print(feature_importance)
# Out:
#                                                feature  importance       std
# 79                                         su_risk_p_1    0.218770  0.090651
# 169                                        macv_p_ss_r    0.140095  0.085040
# 334                                   site_id_l_site16    0.131532  0.280128
# 318                                   stq_y_ss_weekend    0.089308  0.052333
# 148            meim_ethnic_id_p_black/african_american    0.087780  0.128772
# 238                               parent_rules_q1a_3.0    0.083435  0.098449
# 101                                    demo_prnt_ed_v2    0.059891  0.064433
# 33                             reshist_addr1_adi_edu_h    0.059368  0.030149
# 292                                         devhx_18_p    0.056186  0.047462
# 233                                parent_rules_q1_1.0    0.055376  0.030270
# 21                             reshist_addr1_elevation    0.043812  0.068822
# 105                                demo_comb_income_v2    0.042930  0.040013
# 303                           devhx_ss_8_alcohol_max_p    0.033905  0.017714
# 161                                        via_p_ss_hc    0.032251  0.025322
# 95                                     crpbi_parent3_y    0.027776  0.027596
# 305                       devhx_ss_8_alcohol_effects_p    0.026496  0.015179
# 3                                    asr_scr_somatic_t    0.025931  0.021150
# 41                             reshist_addr1_adi_crowd    0.025617  0.027817
# 32                             reshist_addr1_adi_edu_l    0.025341  0.016279
# 167                                      macv_p_ss_isr    0.025340  0.034588
# 304                           devhx_ss_8_alcohol_avg_p    0.025185  0.019850
# 35                            reshist_addr1_adi_income    0.024398  0.022740
# 28                               reshist_addr1_drgsale    0.024008  0.028387
# 317                                   stq_y_ss_weekday    0.023773  0.025080
# 55                            reshist_addr1_pm252016aa    0.023690  0.017511
# 162                                      via_p_ss_amer    0.023669  0.024314
# 166                                       macv_p_ss_fo    0.022846  0.017857
# 254                                parent_rules_q8_3.0    0.022122  0.009970
# 57                      reshist_addr1_leadrisk_housing    0.021847  0.021184
# 44                              reshist_addr1_adi_b138    0.021180  0.043851
# 121                           demo_gender_id_v2_female    0.020352  0.008369
# 23                             reshist_addr1_walkindex    0.020335  0.020226
# 91                                 parent_monitor_q4_y    0.019756  0.021675
# 260                            parent_rules_q1_allowed    0.019425  0.075308
# 42                             reshist_addr1_adi_unemp    0.018712  0.016349
# 62                                        fes_youth_q4    0.017729  0.013617
# 40                            reshist_addr1_adi_home_o    0.017544  0.018170
# 316                                sai_involvement_sum    0.017151  0.010675
# 264                                          devhx_7_p    0.016959  0.012640
# 315                         acs_raked_propensity_score    0.016871  0.013788
# 298                                         devhx_21_p    0.015612  0.020393
# 97                                     crpbi_parent5_y    0.015097  0.013612
# 168                                       macv_p_ss_fr    0.014764  0.017215
# 22                                   reshist_addr1_d1a    0.014677  0.013765
# 94                                     crpbi_parent2_y    0.014626  0.013797
# 37                            reshist_addr1_adi_home_v    0.014150  0.021000
# 120                             demo_gender_id_v2_male    0.013883  0.005034
# 43                               reshist_addr1_adi_pov    0.013861  0.014266
# 119                                 demo_sex_v2_female    0.013739  0.005537
# 100                                   demo_prnt_age_v2    0.013316  0.014804
# 232                                    parent_rules_q2    0.013037  0.007268
# 227                      fam_history_q11d_professional    0.012791  0.009381
# 39                             reshist_addr1_adi_mortg    0.012748  0.019384
# 301                                       birth_weight    0.012069  0.009979
# 61                                        fes_youth_q3    0.011861  0.014945
# 46                              reshist_addr1_adi_ncar    0.011337  0.010232
# 174                                        accult_q5_y    0.011256  0.019050
# 59                                        fes_youth_q1    0.011179  0.009180
# 56                      reshist_addr1_leadrisk_poverty    0.011013  0.012936
# 163                              nsc_p_ss_mean_3_items    0.010989  0.014531
# 11                                   asr_scr_totprob_t    0.010950  0.015897
# 10                                  asr_scr_external_t    0.010835  0.008942
# 177                                        accult_q4_p    0.010518  0.008938
# 24                               reshist_addr1_grndtot    0.010233  0.007147
# 296                                        devhx_19d_p    0.010138  0.019918
# 158                                      meim_p_ss_exp    0.009911  0.007943
# 262                                          devhx_4_p    0.009735  0.012163
# 261                                          devhx_3_p    0.009456  0.011780
# 36                            reshist_addr1_adi_in_dis    0.009437  0.008564
# 83                                         su_risk_p_5    0.009358  0.015778
# 144                   meim_ethnic_id_p_white/caucasian    0.009336  0.004781
# 226                      fam_history_q11a_professional    0.009241  0.008814
# 17                                asr_scr_antisocial_t    0.009224  0.007841
# 31                                   reshist_addr1_dui    0.009204  0.006529
# 34                            reshist_addr1_adi_work_c    0.009159  0.009532
# 15                                  asr_scr_avoidant_t    0.008954  0.010849
# 49                              reshist_addr1_adi_wsum    0.008950  0.010293
# 294                                        devhx_19b_p    0.008773  0.012512
# 300                                        devhx_23b_p    0.008716  0.010131
# 52                                   reshist_addr1_no2    0.008622  0.008785
# 67                                        fes_youth_q9    0.008596  0.006142
# 279                                         devhx_11_p    0.008530  0.014727
# 53                                  reshist_addr1_pm25    0.008431  0.008226
# 263                                          devhx_6_p    0.008380  0.005381
# 51                            reshist_addr1_popdensity    0.008297  0.012726
# 54                                reshist_addr1_proxrd    0.008248  0.007408
# 38                              reshist_addr1_adi_rent    0.008040  0.007028
# 165                                       macv_p_ss_fs    0.007970  0.005745
# 45                                reshist_addr1_adi_sp    0.007877  0.008573
# 160                                    meim_p_ss_total    0.007646  0.008315
# 27                               reshist_addr1_drugtot    0.007504  0.005532
# 48                            reshist_addr1_adi_nplumb    0.007453  0.012625
# 103                                demo_prnt_income_v2    0.007389  0.006417
# 245                                parent_rules_q5_3.0    0.007355  0.004028
# 118                                   demo_sex_v2_male    0.006864  0.002769
# 102                                demo_prnt_empl_time    0.006830  0.004581
# 289                                           devhx_15    0.006720  0.010552
# 293                                        devhx_19a_p    0.006460  0.006942
# 297                                         devhx_20_p    0.006348  0.006285
# 9                                   asr_scr_internal_t    0.006223  0.007223
# 20                                 reshist_addr1_years    0.006152  0.005246
# 312                                      devhx_ss_12_p    0.006151  0.008456
# 295                                        devhx_19c_p    0.006123  0.007741
# 50                              reshist_addr1_adi_perc    0.005950  0.006669
# 178                                        accult_q5_p    0.005916  0.004749
# 29                                reshist_addr1_mjsale    0.005896  0.004428
# 173                                        accult_q4_y    0.005878  0.004460
# 92                                 parent_monitor_q5_y    0.005871  0.008496
# 25                                 reshist_addr1_p1tot    0.005851  0.004124
# 30                               reshist_addr1_drgposs    0.005843  0.004183
# 0                                     asr_scr_perstr_t    0.005740  0.005489
# 64                                        fes_youth_q6    0.005657  0.004905
# 47                              reshist_addr1_adi_ntel    0.005566  0.004848
# 336                                   site_id_l_site18    0.005559  0.015392
# 164                                     fes_p_ss_fc_pr    0.005325  0.003881
# 58                              reshist_addr1_leadrisk    0.005068  0.004935
# 159                                      meim_p_ss_com    0.004821  0.004610
# 6                                 asr_scr_aggressive_t    0.004820  0.010123
# 12                                   asr_scr_depress_t    0.004678  0.006747
# 1                                     asr_scr_anxdep_t    0.004628  0.004821
# 250                                parent_rules_q6_4.0    0.004505  0.004664
# 5                                  asr_scr_attention_t    0.004346  0.005699
# 302                          devhx_ss_8_cigs_per_day_p    0.004239  0.009369
# 242                                parent_rules_q4_1.0    0.004184  0.009364
# 235                                parent_rules_q1_6.0    0.004115  0.005398
# 18                               asr_scr_inattention_t    0.004063  0.004895
# 63                                        fes_youth_q5    0.004049  0.003994
# 4                                    asr_scr_thought_t    0.004021  0.006002
# 87                                         su_risk_p_9    0.004008  0.003622
# 170                                      psb_p_ss_mean    0.003999  0.005760
# 280                                       devhx_13_3_p    0.003799  0.003077
# 80                                         su_risk_p_2    0.003732  0.006088
# 322                                   site_id_l_site04    0.003710  0.007686
# 2                                  asr_scr_withdrawn_t    0.003698  0.005548
# 26                                reshist_addr1_p1vlnt    0.003613  0.002818
# 222                            fam_history_q9a_trouble    0.003550  0.004188
# 320                                   site_id_l_site02    0.003531  0.007766
# 278                                       devhx_10m3_p    0.003454  0.006131
# 126                      demo_prnt_marital_v2_divorced    0.003365  0.005280
# 13                                 asr_scr_anxdisord_t    0.003299  0.003341
# 14                                 asr_scr_somaticpr_t    0.003264  0.003624
# 326                                   site_id_l_site08    0.003159  0.008853
# 171                                        accult_q1_y    0.003143  0.002237
# 203                          fam_history_q5d_drugs___0    0.002964  0.002814
# 93                                     crpbi_parent1_y    0.002931  0.002906
# 85                                         su_risk_p_7    0.002820  0.002000
# 212                         fam_history_q6d_depression    0.002792  0.002521
# 65                                        fes_youth_q7    0.002780  0.004153
# 307                          devhx_ss_9_cigs_per_day_p    0.002749  0.005633
# 290                                         devhx_16_p    0.002745  0.006580
# 7                                  asr_scr_rulebreak_t    0.002659  0.002893
# 16                                      asr_scr_adhd_t    0.002659  0.003466
# 217                                   famhx_4d_p___888    0.002642  0.001555
# 19                               asr_scr_hyperactive_t    0.002552  0.003980
# 306                         devhx_ss_8_marijuana_amt_p    0.002534  0.004646
# 8                                  asr_scr_intrusive_t    0.002472  0.003721
# 291                                         devhx_17_p    0.002445  0.004436
# 251                                parent_rules_q7_1.0    0.002368  0.001963
# 156                             meim_ethnic_id_p_mixed    0.002347  0.007467
# 218                              fam_history_q7a_mania    0.002286  0.003579
# 86                                         su_risk_p_8    0.002255  0.002236
# 211                         fam_history_q6a_depression    0.002111  0.001810
# 324                                   site_id_l_site06    0.002110  0.004668
# 135              demo_prnt_empl_v2_stay_at_home_parent    0.002108  0.002452
# 253                                parent_rules_q8_2.0    0.002088  0.002728
# 89                                 parent_monitor_q2_y    0.002048  0.001852
# 88                                 parent_monitor_q1_y    0.002041  0.002122
# 323                                   site_id_l_site05    0.002011  0.006020
# 81                                         su_risk_p_3    0.001999  0.003377
# 76                                      fam_enviro9r_p    0.001942  0.001343
# 78                             ksads_ptsd_outside_home    0.001908  0.004796
# 172                                        accult_q2_y    0.001838  0.001605
# 77                                     ksads_ptsd_home    0.001824  0.007994
# 244                                parent_rules_q5_2.0    0.001761  0.002266
# 241                                parent_rules_q3_4.0    0.001735  0.002520
# 98                                  crpbi_caregiver1_y    0.001730  0.004215
# 268                                       devhx_10c3_p    0.001672  0.002899
# 71                                      fam_enviro4r_p    0.001660  0.000990
# 332                                   site_id_l_site14    0.001545  0.003425
# 104                                 demo_prnt_prtnr_v2    0.001502  0.002297
# 82                                         su_risk_p_4    0.001493  0.002657
# 286                                       devhx_14f3_p    0.001470  0.002118
# 84                                         su_risk_p_6    0.001448  0.001326
# 195                          fam_history_q5a_drugs___0    0.001413  0.001566
# 147                   meim_ethnic_id_p_hispanic/latino    0.001377  0.002786
# 129           demo_prnt_marital_v2_living_with_partner    0.001332  0.002836
# 308                           devhx_ss_9_alcohol_max_p    0.001294  0.003096
# 228                      fam_history_q12a_hospitalized    0.001221  0.001892
# 134                         demo_prnt_empl_v2_disabled    0.001196  0.004972
# 72                                       fam_enviro5_p    0.001167  0.001219
# 69                                      fam_enviro2r_p    0.001161  0.002324
# 285                                       devhx_14e3_p    0.001142  0.001530
# 90                                 parent_monitor_q3_y    0.001123  0.002084
# 145                  meim_ethnic_id_p_western_european    0.001108  0.005227
# 240                                parent_rules_q3_1.0    0.001056  0.002372
# 224                            fam_history_q10a_nerves    0.001047  0.001538
# 231                           fam_history_q13d_suicide    0.001039  0.001713
# 282                                       devhx_14b3_p    0.001037  0.003080
# 266                                       devhx_10a3_p    0.001036  0.001437
# 225                            fam_history_q10d_nerves    0.001028  0.001360
# 230                           fam_history_q13a_suicide    0.001026  0.001421
# 237                               parent_rules_q1a_2.0    0.001023  0.000985
# 288                                       devhx_14h3_p    0.001016  0.002804
# 243                                parent_rules_q5_1.0    0.001010  0.004441
# 325                                   site_id_l_site07    0.001007  0.003160
# 176                                        accult_q2_p    0.001005  0.000917
# 219                              fam_history_q7d_mania    0.001005  0.002346
# 99                                  demo_adopt_agex_v2    0.000997  0.005922
# 124                       demo_prnt_marital_v2_married    0.000986  0.001248
# 130                      demo_prnt_empl_v2_working_now    0.000985  0.001262
# 66                                        fes_youth_q8    0.000984  0.001210
# 259                                parent_rules_q9_5.0    0.000964  0.001207
# 221                            fam_history_q8d_visions    0.000956  0.001634
# 179                                     famhx_4d_p___0    0.000943  0.000884
# 223                            fam_history_q9d_trouble    0.000919  0.001221
# 122                        demo_prnt_gender_id_v2_male    0.000893  0.002268
# 273                                       devhx_10h3_p    0.000873  0.001577
# 274                                       devhx_10i3_p    0.000871  0.001964
# 60                                        fes_youth_q2    0.000829  0.000859
# 310                       devhx_ss_9_alcohol_effects_p    0.000798  0.001929
# 111                                   demo_fam_exp6_v2    0.000793  0.002349
# 339                                   site_id_l_site21    0.000791  0.001974
# 68                                       fam_enviro1_p    0.000789  0.001340
# 108                                   demo_fam_exp3_v2    0.000784  0.002231
# 229                      fam_history_q12d_hospitalized    0.000779  0.000849
# 309                           devhx_ss_9_alcohol_avg_p    0.000768  0.001988
# 333                                   site_id_l_site15    0.000765  0.002519
# 106                                   demo_fam_exp1_v2    0.000765  0.001588
# 198                          fam_history_q5a_drugs___3    0.000760  0.001666
# 299                                       devhx_22_3_p    0.000704  0.000781
# 283                                       devhx_14c3_p    0.000690  0.001764
# 265                                           devhx_10    0.000668  0.001265
# 281                                       devhx_14a3_p    0.000662  0.001471
# 272                                       devhx_10g3_p    0.000641  0.001867
# 74                                      fam_enviro7r_p    0.000622  0.000945
# 220                            fam_history_q8a_visions    0.000607  0.001115
# 73                                       fam_enviro6_p    0.000589  0.001063
# 275                                       devhx_10j3_p    0.000576  0.001065
# 208                          fam_history_q5d_drugs___4    0.000569  0.003340
# 137                            demo_prnt_empl_v2_other    0.000556  0.002133
# 175                                        accult_q1_p    0.000551  0.001163
# 311                         devhx_ss_9_marijuana_amt_p    0.000539  0.001682
# 128                 demo_prnt_marital_v2_never_married    0.000519  0.001683
# 246                                parent_rules_q6_0.0    0.000473  0.001437
# 113                        demo_prim_biological_mother    0.000469  0.000789
# 187                                      famhx4a_p___0    0.000468  0.000736
# 143                              meim_ethnic_id_p_none    0.000467  0.000959
# 123                      demo_prnt_gender_id_v2_female    0.000460  0.000892
# 335                                   site_id_l_site17    0.000453  0.001424
# 127                     demo_prnt_marital_v2_separated    0.000446  0.002273
# 114                        demo_prim_biological_father    0.000446  0.000866
# 196                          fam_history_q5a_drugs___1    0.000430  0.001082
# 204                          fam_history_q5d_drugs___1    0.000424  0.002378
# 190                                      famhx4a_p___3    0.000413  0.000812
# 329                                   site_id_l_site11    0.000410  0.001118
# 112                                   demo_fam_exp7_v2    0.000395  0.001085
# 75                                       fam_enviro8_p    0.000387  0.000549
# 338                                   site_id_l_site20    0.000380  0.001334
# 107                                   demo_fam_exp2_v2    0.000379  0.000760
# 277                                       devhx_10l3_p    0.000364  0.001205
# 270                                       devhx_10e3_p    0.000352  0.003002
# 328                                   site_id_l_site10    0.000346  0.000889
# 255                                parent_rules_q9_1.0    0.000339  0.001151
# 194                                      famhx4a_p___6    0.000337  0.000935
# 116                         demo_prim_custodial_parent    0.000318  0.001641
# 96                                     crpbi_parent4_y    0.000317  0.000763
# 189                                      famhx4a_p___2    0.000302  0.000902
# 197                          fam_history_q5a_drugs___2    0.000300  0.000813
# 258                                parent_rules_q9_4.0    0.000295  0.001075
# 70                                       fam_enviro3_p    0.000286  0.000539
# 205                          fam_history_q5d_drugs___2    0.000277  0.001232
# 327                                   site_id_l_site09    0.000268  0.000598
# 192                                      famhx4a_p___4    0.000255  0.000753
# 110                                   demo_fam_exp5_v2    0.000252  0.000670
# 201                          fam_history_q5a_drugs___5    0.000251  0.000836
# 337                                   site_id_l_site19    0.000248  0.000976
# 267                                       devhx_10b3_p    0.000225  0.000593
# 202                          fam_history_q5a_drugs___6    0.000221  0.000627
# 200                          fam_history_q5a_drugs___4    0.000208  0.000499
# 331                                   site_id_l_site13    0.000203  0.000549
# 321                                   site_id_l_site03    0.000189  0.000516
# 276                                       devhx_10k3_p    0.000187  0.000606
# 236                               parent_rules_q1a_1.0    0.000181  0.000716
# 199                          fam_history_q5a_drugs___7    0.000175  0.000522
# 182                                     famhx_4d_p___3    0.000173  0.000583
# 314                   devhx_ss_her_morph_oxycont_amt_p    0.000154  0.000515
# 330                                   site_id_l_site12    0.000150  0.000397
# 191                                      famhx4a_p___7    0.000149  0.000446
# 188                                      famhx4a_p___1    0.000135  0.000357
# 287                                       devhx_14g3_p    0.000132  0.000438
# 214                                    famhx4a_p___999    0.000130  0.000671
# 319                                   site_id_l_site01    0.000128  0.000480
# 132                 demo_prnt_empl_v2_looking_for_work    0.000115  0.000337
# 184                                     famhx_4d_p___4    0.000110  0.000582
# 115                          demo_prim_adoptive_parent    0.000110  0.000432
# 215                        fam_history_q5a_drugs___999    0.000109  0.000473
# 153     meim_ethnic_id_p_american_indian/alaska_native    0.000107  0.000667
# 247                                parent_rules_q6_1.0    0.000104  0.000790
# 181                                     famhx_4d_p___2    0.000104  0.000555
# 206                          fam_history_q5d_drugs___3    0.000090  0.000356
# 193                                      famhx4a_p___5    0.000088  0.000422
# 207                          fam_history_q5d_drugs___7    0.000080  0.000450
# 252                                parent_rules_q8_1.0    0.000079  0.000379
# 136                          demo_prnt_empl_v2_student    0.000078  0.000359
# 210                          fam_history_q5d_drugs___6    0.000063  0.000268
# 269                                       devhx_10d3_p    0.000063  0.000354
# 150                        meim_ethnic_id_p_east_asian    0.000054  0.000237
# 186                                     famhx_4d_p___6    0.000049  0.000200
# 340                                   site_id_l_site22    0.000047  0.000404
# 248                                parent_rules_q6_2.0    0.000043  0.000268
# 271                                       devhx_10f3_p    0.000043  0.000213
# 183                                     famhx_4d_p___7    0.000042  0.000252
# 209                          fam_history_q5d_drugs___5    0.000041  0.000299
# 313                           devhx_ss_coc_crack_amt_p    0.000038  0.000147
# 249                                parent_rules_q6_3.0    0.000034  0.000134
# 117                                    demo_prim_other    0.000029  0.000169
# 152                   meim_ethnic_id_p_southeast_asian    0.000028  0.000175
# 133                          demo_prnt_empl_v2_retired    0.000020  0.000149
# 284                                       devhx_14d3_p    0.000016  0.000087
# 180                                     famhx_4d_p___1    0.000016  0.000111
# 146                  meim_ethnic_id_p_eastern_european    0.000015  0.000172
# 149  meim_ethnic_id_p_afro-carribean/indo-carribbea...    0.000011  0.000121
# 155  meim_ethnic_id_p_native_hawaiian_or_pacific_is...    0.000009  0.000109
# 125                       demo_prnt_marital_v2_widowed    0.000008  0.000065
# 213                                   famhx_4d_p___999    0.000006  0.000070
# 216                        fam_history_q5d_drugs___999    0.000006  0.000069
# 154      meim_ethnic_id_p_middle_eastern/north_african    0.000004  0.000052
# 234                                parent_rules_q1_5.0    0.000004  0.000052
# 131             demo_prnt_empl_v2_temporarily_laid_off    0.000004  0.000037
# 157                             meim_ethnic_id_p_other    0.000000  0.000000
# 142                  demo_prnt_gender_id_v2_non-binary    0.000000  0.000000
# 185                                     famhx_4d_p___5    0.000000  0.000000
# 239                                parent_rules_q3_0.0    0.000000  0.000000
# 141                       demo_gender_id_v2_non-binary    0.000000  0.000000
# 140           demo_prnt_empl_v2_unemployed_not_looking    0.000000  0.000000
# 139                  demo_prnt_empl_v2_maternity_leave    0.000000  0.000000
# 138                       demo_prnt_empl_v2_sick_leave    0.000000  0.000000
# 109                                   demo_fam_exp4_v2    0.000000  0.000000
# 256                                parent_rules_q9_2.0    0.000000  0.000000
# 257                                parent_rules_q9_3.0    0.000000  0.000000
# 151                       meim_ethnic_id_p_south_asian    0.000000  0.000000

# %%
plt.style.use('default')
shap.summary_plot(shap_values, X_display)

# %%
new_api_shap_values = explainer(X)

top_inds = np.argsort(-np.sum(np.abs(new_api_shap_values.values), 0))
for i in range(20):
    shap.plots.scatter(new_api_shap_values[:, top_inds[i]], color=new_api_shap_values)
